# %%
import os
import json

import numpy as np
import pandas as pd
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import cdist, mahalanobis
from sklearn.cluster import AgglomerativeClustering
from itertools import combinations
from collections import defaultdict

import numpy as np
import pandas as pd
from scipy.spatial.distance import squareform
from scipy.stats import rankdata
from sklearn.cluster import AgglomerativeClustering

QUESTIONS_FILE = "./data/questions_filter_after.json"
POLICIES_FILE = "./data/policies_testing.json"
OUTPUT_Q_FILE = "./output_q.json"
OUTPUT_P_FILE = "./output_p.json"


def _loadJson(filepath):
	if not os.path.exists(filepath):
		print(f"Warning: File not found: {filepath}")
		return {}
	try:
		with open(filepath, "r", encoding="utf-8") as f:
			return json.load(f)
	except json.JSONDecodeError:
		print(f"Error decoding JSON: {filepath}")
		return {}


qdata = _loadJson(QUESTIONS_FILE)


def prepare_model_artifacts(raw_vector_list, name="Model"):
	print(f"Processing {name}...")
	data = np.array(raw_vector_list)
	data_trunc = data[:, :256]
	norms = np.linalg.norm(data_trunc, axis=1, keepdims=True)
	cleaned_vectors = data_trunc / (norms + 1e-10)

	lw = LedoitWolf()
	lw.fit(cleaned_vectors)
	precision_matrix = lw.precision_

	dist_matrix = cdist(
		cleaned_vectors, cleaned_vectors, metric="mahalanobis", VI=precision_matrix
	)

	return {
		"dist_matrix": dist_matrix,
		"vectors": cleaned_vectors,
		"precision": precision_matrix,
	}


# --- LOAD DATA ---
data_set = qdata
strings = list(data_set.keys())

raw_vectors_A = [data_set[s]["embedding_vector"] for s in strings]
raw_vectors_B = [data_set[s]["retrieval_embedding_vector"] for s in strings]

Model_A = prepare_model_artifacts(raw_vectors_A, "Model A (Statement)")
Model_B = prepare_model_artifacts(raw_vectors_B, "Model B (Question)")


def get_pairs_from_labels(labels):
	"""Converts cluster labels into a Set of unique pairs (indices)."""
	df = pd.DataFrame({"label": labels, "id": range(len(labels))})
	pairs = set()
	for label, group in df.groupby("label"):
		indices = group["id"].tolist()
		if len(indices) > 1:
			for p in combinations(sorted(indices), 2):
				pairs.add(p)
	return pairs


def get_clustering_pairs_and_labels(dist_matrix, threshold):
	"""Runs clustering and returns both the pair set and the labels array."""
	model = AgglomerativeClustering(
		n_clusters=None,
		distance_threshold=threshold,
		metric="precomputed",
		linkage="complete",
	)
	labels = model.fit_predict(dist_matrix)
	return get_pairs_from_labels(labels), labels


def calculate_n_true(labels_array, target_pairs):
	"""Calculates the number of unique clusters containing the elements of target_pairs."""
	if not target_pairs or labels_array is None:
		return 0

	involved_indices = set(idx for pair in target_pairs for idx in pair)

	labels_of_interest = set(
		labels_array[idx] for idx in involved_indices if idx < len(labels_array)
	)

	if not involved_indices:
		return 0

	return len(labels_of_interest)


print("\n--- Phase 1: Grid Search for Consensus (Tau) ---")


dist_A_off = Model_A["dist_matrix"][np.triu_indices_from(Model_A["dist_matrix"], k=1)]
dist_B_off = Model_B["dist_matrix"][np.triu_indices_from(Model_B["dist_matrix"], k=1)]
all_dists = np.concatenate([dist_A_off, dist_B_off])


D_min_min = np.min(all_dists)
D_max_max = np.max(all_dists)


SEARCH_STEP = 0.2


TAU_SEARCH_START = max(D_min_min, 0.0)
TAU_SEARCH_END = D_max_max

tau_range = np.arange(TAU_SEARCH_START, TAU_SEARCH_END, SEARCH_STEP)
t_range = np.arange(TAU_SEARCH_START, TAU_SEARCH_END, SEARCH_STEP)

print(
	f"Search Range Defined: [{TAU_SEARCH_START:.2f} to {TAU_SEARCH_END:.2f}] (Step: {SEARCH_STEP})"
)
best_jaccard = -1
P_true = set()
labels_A_star = None
labels_B_star = None


cache_A = {}
cache_B = {}

print(f"Pre-computing clusters for {len(tau_range)} thresholds...")
for t in tau_range:
	cache_A[t] = get_clustering_pairs_and_labels(Model_A["dist_matrix"], t)
	cache_B[t] = get_clustering_pairs_and_labels(Model_B["dist_matrix"], t)
TAU_A = 0
TAU_B = 0

for t_A in tau_range:
	pairs_A, labels_A = cache_A[t_A]
	for t_B in tau_range:
		pairs_B, labels_B = cache_B[t_B]

		intersection = pairs_A.intersection(pairs_B)
		union = pairs_A.union(pairs_B)

		if len(union) > 0:
			jaccard = len(intersection) / len(union)
			if jaccard > best_jaccard:

				best_jaccard = jaccard
				P_true = intersection
				labels_A_star = labels_A
				labels_B_star = labels_B
				TAU_A = t_A
				TAU_B = t_B


print(f"tau a:{TAU_A}, tau b:{TAU_B}")


N_A_true = calculate_n_true(labels_A_star, P_true)
N_B_true = calculate_n_true(labels_B_star, P_true)
N_target = (N_A_true + N_B_true) / 2

print(f"\nConsensus Structure Found:")
print(f"Platinum Pairs Identified: {len(P_true)}")
print(f"N_target: {N_target:.1f} (Avg of A={N_A_true}, B={N_B_true})")


print("\n--- Phase 2: Tuning Thresholds to Target N_target ---")


def tune_threshold_by_group_count(model_data, N_target, model_name):
	best_t = 0
	min_error = float("inf")
	best_f1 = -1

	for t in t_range:
		current_pairs, current_labels = get_clustering_pairs_and_labels(
			model_data["dist_matrix"], t
		)

		N_predicted = calculate_n_true(current_labels, P_true)
		group_error = abs(N_predicted - N_target)

		tp = len(current_pairs.intersection(P_true))
		fp = len(current_pairs - P_true)
		fn = len(P_true - current_pairs)

		if tp > 0:
			precision = tp / (tp + fp)
			recall = tp / (tp + fn)
			f1 = 2 * (precision * recall) / (precision + recall)
		else:
			f1 = 0

		if group_error < min_error:
			min_error = group_error
			best_f1 = f1
			best_t = t
		elif group_error == min_error and f1 > best_f1:
			best_f1 = f1
			best_t = t

	print(
		f"[{model_name}] Optimal t: {best_t:.1f} | Group Error: {min_error:.1f} | F1: {best_f1:.4f}"
	)
	return best_t


optimal_t_A = tune_threshold_by_group_count(Model_A, N_target, "Model A")
optimal_t_B = tune_threshold_by_group_count(Model_B, N_target, "Model B")

print(f"\nFinal Calibrated Thresholds:")
print(f"Model A (Statement): {optimal_t_A:.2f}")
print(f"Model B (Question):  {optimal_t_B:.2f}")


def print_final_clusters(model_data, threshold, string_list, title):
	print(f"\n{'='*80}")
	print(f"FINAL OUTPUT: {title} (Threshold: {threshold:.2f})")
	print(f"{'='*80}")

	cluster_model = AgglomerativeClustering(
		n_clusters=None,
		distance_threshold=threshold,
		metric="precomputed",
		linkage="complete",
	)
	labels = cluster_model.fit_predict(model_data["dist_matrix"])

	df = pd.DataFrame(
		{"string": string_list, "label": labels, "idx": range(len(string_list))}
	)
	groups = [g for _, g in df.groupby("label") if len(g) > 1]
	groups.sort(key=lambda x: len(x), reverse=True)

	final_pairs, _ = get_clustering_pairs_and_labels(model_data["dist_matrix"], threshold)
	tp = len(final_pairs.intersection(P_true))
	fp = len(final_pairs - P_true)

	print(f"Found {len(groups)} total significant groups.")
	print(f"P_true pairs captured: {tp} (False Positives: {fp})\n")

	for i, group in enumerate(groups):
		indices = group["idx"].tolist()
		cluster_strs = group["string"].tolist()

		vecs = model_data["vectors"][indices]
		prec = model_data["precision"]
		local_mean = np.mean(vecs, axis=0)

		distances = []
		min_dist = float("inf")
		rep_idx = -1

		for local_i, global_i in enumerate(indices):
			d = mahalanobis(model_data["vectors"][global_i], local_mean, prec)
			distances.append(d)
			if d < min_dist:
				min_dist = d
				rep_idx = local_i

		group_radius = max(distances)

		print(f"GROUP {i+1} (Size: {len(indices)}) [Radius: {group_radius:.4f}]")

		for idx, s in enumerate(cluster_strs):
			prefix = " [CENTROID] " if idx == rep_idx else "            "
			print(f"{prefix} {s}")
		print("-" * 80)


print_final_clusters(Model_A, optimal_t_A, strings, "Model A (Statement Embeddings)")
print_final_clusters(Model_B, optimal_t_B, strings, "Model B (Question Embeddings)")


def get_nearest_neighbor_distances(dist_matrix):
	"""
	Extracts the distance to the nearest neighbor for every point.
	Ignores the diagonal (0).
	"""
	np.fill_diagonal(dist_matrix, float("inf"))
	min_dists = np.min(dist_matrix, axis=1)
	np.fill_diagonal(dist_matrix, 0.0)
	return min_dists


def convert_dist_to_prob(dist_matrix, reference_dist_array):
	"""
	Converts raw distances into Probabilities (P-values) based on the
	Empirical CDF of the provided reference distribution (Nearest Neighbors).

	P(d) = (Rank of d) / (Total Count + 1)
	"""

	sorted_refs = np.sort(reference_dist_array)
	n = len(sorted_refs)

	ranks = np.searchsorted(sorted_refs, dist_matrix)

	probs = (ranks + 1) / (n + 1)

	return probs


print("--- Calculating Empirical Probabilities (EVT Logic) ---")


nn_dists_A = get_nearest_neighbor_distances(Model_A["dist_matrix"])
nn_dists_B = get_nearest_neighbor_distances(Model_B["dist_matrix"])


Prob_A = convert_dist_to_prob(Model_A["dist_matrix"], nn_dists_A)
Prob_B = convert_dist_to_prob(Model_B["dist_matrix"], nn_dists_B)

print(f"Probabilities Calculated.")
print(
	f"Example (Model A): Dist=8.8 -> P={np.interp(8.8, np.sort(nn_dists_A), np.linspace(0,1,len(nn_dists_A))):.5f}"
)
print(
	f"Example (Model B): Dist=8.8 -> P={np.interp(8.8, np.sort(nn_dists_B), np.linspace(0,1,len(nn_dists_B))):.5f}"
)


print("\n--- Fusing Probabilities (Min Rule) ---")


Prob_Fused = np.minimum(Prob_A, Prob_B)


print("\n--- Inferring Threshold from Platinum Pairs ---")

platinum_probs = []
for idx1, idx2 in P_true:
	p_val = Prob_Fused[idx1, idx2]
	platinum_probs.append(p_val)

# HARDCODED_MAX_A_SIZE = 105
# HARDCODED_MAX_STABLE_B_SIZE = 99
# AV_STABLE = (HARDCODED_MAX_A_SIZE + HARDCODED_MAX_STABLE_B_SIZE) / 2

# AV_STABLE = (getMaxStable(TAU_A, ...) + getMaxStable(TAU_B, ...)) / 2
AV_STABLE = (getMaxStable(TAU_A, Model_A) + getMaxStable(TAU_B, Model_B)) / 2
# PROB_THRESHOLD = len(P_true) / (AV_STABLE)
PROB_THRESHOLD = len(P_true) / (AV_STABLE)

print(f"Inferred Probability Threshold: {PROB_THRESHOLD:.6f}")


print(f"\n{'='*80}")
print(f"STAGE 2 OUTPUT: Probabilistic Outlier Model (P < {PROB_THRESHOLD:.6f})")
print(f"{'='*80}")


cluster_model = AgglomerativeClustering(
	n_clusters=None,
	distance_threshold=PROB_THRESHOLD,
	metric="precomputed",
	linkage="complete",
)

labels = cluster_model.fit_predict(Prob_Fused)


df = pd.DataFrame({"string": strings, "label": labels, "idx": range(len(strings))})
groups = [g for _, g in df.groupby("label") if len(g) > 1]
groups.sort(key=lambda x: len(x), reverse=True)

print(f"Found {len(groups)} significant groups.\n")

for i, group in enumerate(groups):
	indices = group["idx"].tolist()
	cluster_strs = group["string"].tolist()

	ref_vectors = Model_B["vectors"][indices]
	ref_prec = Model_B["precision"]
	local_mean = np.mean(ref_vectors, axis=0)

	dists = []
	min_d = float("inf")
	rep_i = -1

	for loc_i, glob_i in enumerate(indices):
		d = mahalanobis(Model_B["vectors"][glob_i], local_mean, ref_prec)
		dists.append(d)
		if d < min_d:
			min_d = d
			rep_i = loc_i

	print(f"GROUP {i+1} (Size: {len(indices)}) [Radius: {max(dists):.4f}]")

	for idx, s in enumerate(cluster_strs):
		prefix = " [CENTROID] " if idx == rep_i else "            "
		print(f"{prefix} {s}")
	print("-" * 80)
# Out:
# Processing Model A (Statement)...
# Processing Model B (Question)...
#
# --- Phase 1: Grid Search for Consensus (Tau) ---
# Search Range Defined: [5.77 to 25.35] (Step: 0.2)
# Pre-computing clusters for 98 thresholds...
# tau a:24.97308635455024, tau b:24.57308635455024
#
# Consensus Structure Found:
# Platinum Pairs Identified: 133904
# N_target: 1.5 (Avg of A=2, B=1)
#
# --- Phase 2: Tuning Thresholds to Target N_target ---
# [Model A] Optimal t: 25.0 | Group Error: 0.5 | F1: 1.0000
# [Model B] Optimal t: 24.6 | Group Error: 0.5 | F1: 0.9961
#
# Final Calibrated Thresholds:
# Model A (Statement): 24.97
# Model B (Question):  24.57
#
# ================================================================================
# FINAL OUTPUT: Model A (Statement Embeddings) (Threshold: 24.97)
# ================================================================================
# Found 2 total significant groups.
# P_true pairs captured: 133904 (False Positives: 0)
#
# GROUP 1 (Size: 518) [Radius: 17.6866]
#              Does the privacy policy affirm that the company implements appropriate technical security measures?
#              Does the privacy policy affirm that the company implements appropriate organizational security measures?
#              Does the privacy policy affirm that security measures are designed to protect personal data from loss?
#              Does the privacy policy affirm that security measures are designed to protect personal data from misuse?
#              Does the privacy policy affirm that security measures are designed to protect personal data from unauthorized access?
#              Does the privacy policy affirm that security measures are designed to protect personal data from unauthorized disclosure?
#              Does the privacy policy affirm that security measures are designed to protect personal data from unauthorized alteration?
#              Does the privacy policy affirm that security measures are designed to protect personal data from unauthorized destruction?
#              Does the privacy policy affirm that the Services are not directed to children under 13?
#              Does the privacy policy affirm that the Services are not intended for children under 13?
#              Does the privacy policy affirm that the company does not knowingly collect Personal Data from children under 13?
#              Does the privacy policy affirm that users should contact the company via email if they believe a child under 13 has provided Personal Data to the company?
#              Does the privacy policy affirm that the company will investigate notifications regarding Personal Data provided by children under 13?
#              Does the privacy policy affirm that the company will delete Personal Data from its systems if appropriate following an investigation?
#              Does the privacy policy affirm that users under 18 must have permission from their parent or guardian to use the Services?
#              Does the privacy policy affirm that the company's services are not directed towards children under the age of 18?
#              Does the privacy policy affirm that the company does not knowingly collect information from children under the age of 18?
#              Does the privacy policy affirm that the company does not knowingly disclose information from children under the age of 18?
#              Does the privacy policy affirm that the company does not knowingly sell information from children under the age of 18?
#              Does the privacy policy affirm that the company does not knowingly share information from children under the age of 18?
#              Does the privacy policy affirm that users should contact the company via email if they become aware that a child under 18 has provided personal data?
#              Does the privacy policy affirm that the company will investigate reports regarding personal data provided by a child under the age of 18?
#              Does the privacy policy affirm that the company will delete personal data provided by a child under the age of 18 if deemed appropriate after investigation?
#              Does the privacy policy affirm that the company implements commercially reasonable technical measures to protect Personal Data?
#              Does the privacy policy affirm that the company implements commercially reasonable administrative measures to protect Personal Data?
#              Does the privacy policy affirm that the company implements commercially reasonable organizational measures to protect Personal Data?
#              Does the privacy policy affirm that no Internet or email transmission is ever fully secure or error free?
#              Does the privacy policy affirm that users should take special care in deciding what information they provide to the services?
#              Does the privacy policy affirm that the company is not responsible for the circumvention of any privacy settings contained on the service?
#              Does the privacy policy affirm that the company is not responsible for the circumvention of any security measures contained on the service?
#              Does the privacy policy affirm that the company is not responsible for the circumvention of privacy settings or security measures on third-party websites?
#              Does the privacy policy affirm that users can contact support if they have questions or concerns not already addressed in the Privacy Policy?
#              Does the privacy policy affirm that users can write to the company via email regarding their questions or concerns?
#              Does the privacy policy affirm that users can write to the company at the address listed under the Data Controller section?
#              Does the privacy policy affirm that the Data Protection Officer can be contacted via email regarding matters related to Personal Data processing?
#              Does the privacy policy affirm that the company obtains personal data from third-party sources to train its models?
#              Does the privacy policy affirm that the company trains its models using publicly available information from the Internet?
#              Does the privacy policy affirm that the company trains its models using datasets obtained through commercial agreements with third-party businesses?
#              Does the privacy policy affirm that the company trains its models using data provided by users?
#              Does the privacy policy affirm that the company trains its models using data provided by crowd workers?
#              Does the privacy policy affirm that the company trains its models using inputs and outputs from its services, unless users opt out?
#              Does the privacy policy affirm that the company trains its models using feedback that users explicitly provide about the services?
#              Does the privacy policy affirm that the company trains its models using materials flagged for safety, security, or policy review?
#              Does the privacy policy affirm that the company trains its models using data generated internally?
#              Does the privacy policy affirm that accessing the website or services may result in the transfer of personal data to servers in the US?
#              Does the privacy policy affirm that personal data may be transferred to countries outside the European Economic Area (EEA)?
#              Does the privacy policy affirm that personal data may be transferred to countries outside the UK?
#              Does the privacy policy affirm that international data transfers may occur via direct provision of personal data by the user to the company?
#              Does the privacy policy affirm that international data transfers may be executed by the company itself?
#              Does the privacy policy affirm that international data transfers may be executed by a third party?
#              Does the privacy policy affirm that the company ensures an adequate level of data protection for information transferred outside the EEA or the UK?
#              Does the privacy policy affirm that the company relies on adequacy decisions for some international data transfers?
#              Does the privacy policy affirm that the company relies on Standard Contractual Clauses (SCCs) for transfers to countries without an adequacy decision?
#              Does the privacy policy affirm that the company uses Standard Contractual Clauses to transfer information to certain affiliates?
#              Does the privacy policy affirm that the company uses Standard Contractual Clauses to transfer information to third parties?
#              Does the privacy policy affirm that the company may rely on derogations provided under applicable data protection law to transfer information to a third country in certain situations?
#              Does the privacy policy affirm that it describes practices regarding Personal Data collected when using the company's website?
#              Does the privacy policy affirm that it describes practices regarding Personal Data collected when using the company's applications?
#              Does the privacy policy affirm that it describes practices regarding Personal Data collected when using the company's services?
#              Does the privacy policy affirm that it does not apply to content processed on behalf of customers of the company's business offerings?
#              Does the privacy policy affirm that the use of data processed on behalf of business customers is governed by separate customer agreements?
#              Does the privacy policy affirm that it explains how the company collects, uses, discloses, and processes personal data when acting as a data controller?
#              Does the privacy policy affirm that it applies when users interact with the company's products as a consumer for personal use?
#              Does the privacy policy affirm that it applies when the company provides commercial customers with access to commercial products?
#              Does the privacy policy affirm that it does not apply where the company acts as a data processor?
#              Does the privacy policy affirm that it does not apply when processing personal data on behalf of commercial customers using the company's commercial services?
#              Does the privacy policy affirm that the commercial customer is the controller when the company processes data on behalf of that customer?
#              Does the privacy policy affirm that information regarding how Large Language Models are trained is located in the Non-User Privacy Policy?
#              Does the privacy policy affirm that information regarding how personal data obtained from third-party sources is used can be found in the Non-User Privacy Policy?
#              Does the privacy policy affirm that it describes the user's privacy rights?
#              Does the privacy policy affirm that the company retains personal data for as long as reasonably necessary for the purposes outlined in the policy?
#              Does the privacy policy affirm that retention criteria are further explained in the company's privacy center?
#              Does the privacy policy affirm that the company performs necessary procedures for handling data when it is no longer required?
#              Does the privacy policy affirm that service providers perform necessary procedures for handling data when it is no longer required?
#              Does the privacy policy affirm that personal data may be destroyed, deleted, or erased when it is no longer required?
#              Does the privacy policy affirm that personal data may be converted into an anonymous form when it is no longer required?
#              Does the privacy policy affirm that the disposal or anonymization of data is performed as permitted or required under applicable laws?
#              Does the privacy policy affirm that the company processes Personal Data on servers located outside of the EEA?
#              Does the privacy policy affirm that the company processes Personal Data on servers located outside of Switzerland?
#              Does the privacy policy affirm that the company processes Personal Data on servers located outside of the UK?
#              Does the privacy policy affirm that the company processes Personal Data in the United States?
#              Does the privacy policy affirm that the company stores Personal Data in facilities and servers in the United States?
#              Does the privacy policy affirm that countries where data is processed may not offer the same level of data protection as the user's home country?
#              Does the privacy policy affirm that the company applies the protections described in the policy to Personal Data regardless of where it is processed?
#              Does the privacy policy affirm that the company relies on the European Commission’s adequacy decisions when transferring Personal Data to countries considered to provide adequate protection?
#              Does the privacy policy affirm that the company relies on Standard Contractual Clauses (SCCs) for transfers to jurisdictions without adequacy decisions?
#              Does the privacy policy affirm that the company relies on the UK Data Transfer Addendum for data transfers?
#              Does the privacy policy affirm that users can contact the company to obtain a copy of the appropriate safeguards in place for data transfers?
#              Does the privacy policy affirm that users can contact the company via email regarding data transfer safeguards?
#              Does the privacy policy affirm that the company has designated a domestic representative for data protection purposes in the Republic of Korea?
#              Does the privacy policy affirm that the domestic representative acts in compliance with the Personal Information Protection Act?
#              Does the privacy policy affirm that the domestic representative acts in compliance with the Act on Promotion of Information and Communications Network Utilization and Data Protection?
#              Does the privacy policy affirm that the domestic representative is located in South Korea?
#              Does the privacy policy affirm that users can contact the domestic representative via telephone?
#              Does the privacy policy affirm that users can contact the domestic representative via email?
#              Does the privacy policy affirm that the company utilizes trustees to assist with domestic representative duties?
#              Does the privacy policy affirm that user names are entrusted to the domestic representative?
#              Does the privacy policy affirm that user IDs are entrusted to the domestic representative?
#              Does the privacy policy affirm that user phone numbers are entrusted to the domestic representative?
#              Does the privacy policy affirm that user email addresses are entrusted to the domestic representative?
#              Does the privacy policy affirm that user addresses are entrusted to the domestic representative?
#              Does the privacy policy affirm that the recipient location for entrusted data is South Korea?
#              Does the privacy policy affirm that the retention period for data entrusted to the representative is the period necessary to process the user's request?
#              Does the privacy policy affirm that data transfer methods to the representative include telephone?
#              Does the privacy policy affirm that data transfer methods to the representative include text?
#              Does the privacy policy affirm that data transfer methods to the representative include email?
#              Does the privacy policy affirm that Account Information is processed to provide, analyze, and maintain the services?
#              Does the privacy policy affirm that User Content is processed to provide, analyze, and maintain the services?
#              Does the privacy policy affirm that Location Information is processed to provide, analyze, and maintain the services?
#              Does the privacy policy affirm that processing user prompts to provide a response is based on the necessity to perform a contract?
#              Does the privacy policy affirm that User Content is processed to improve and develop services and conduct research?
#              Does the privacy policy affirm that data received from other sources is processed to improve and develop services?
#              Does the privacy policy affirm that the company processes data to train and improve models based on legitimate interests?
#              Does the privacy policy affirm that Social Media Information is processed to communicate with the user?
#              Does the privacy policy affirm that processing contact information to send technical announcements is based on the necessity to perform a contract?
#              Does the privacy policy affirm that the company relies on user consent to process contact information for specific marketing communications?
#              Does the privacy policy affirm that data received from other sources is processed to prevent fraud and illegal activity?
#              Does the privacy policy affirm that the company processes data from security partners to protect against fraud based on legitimate interests?
#              Does the privacy policy affirm that Log Data is analyzed to identify fraud and abuse in the services?
#              Does the privacy policy affirm that transaction information is retained to comply with record-keeping obligations?
#              Does the privacy policy affirm that the company processes device information to protect the rights, privacy, safety, or property of users or the company?
#              Does the privacy policy affirm that personal data may be processed in an aggregated form?
#              Does the privacy policy affirm that personal data may be processed in a de-identified form?
#              Does the privacy policy affirm that the company processes aggregated or de-identified data to analyze the effectiveness of its services?
#              Does the privacy policy affirm that the company processes aggregated or de-identified data to conduct research?
#              Does the privacy policy affirm that the company processes aggregated or de-identified data to study user behavior?
#              Does the privacy policy affirm that the company processes aggregated or de-identified data to train AI models as permitted under applicable laws?
#              Does the privacy policy affirm that Inputs and Outputs are disassociated from the user ID when a user submits Feedback?
#              Does the privacy policy affirm that Inputs and Outputs disassociated via Feedback are used for training models?
#              Does the privacy policy affirm that Inputs and Outputs disassociated via Feedback are used for improving models?
#              Does the privacy policy affirm that Inputs or Outputs flagged for potentially violating the Usage Policy are disassociated from the user ID?
#              Does the privacy policy affirm that content flagged for potential violations is used to train internal trust and safety classification models?
#              Does the privacy policy affirm that content flagged for potential violations is used to train generative models?
#              Does the privacy policy affirm that the company may re-identify Inputs or Outputs to enforce the Usage Policy?
#              Does the privacy policy affirm that general user behavior may be analyzed and aggregated to improve user experience?
#              Does the privacy policy affirm that analyzed and aggregated general user behavior data does not identify individual users?
#              Does the privacy policy affirm that the company retains Personal Data only as long as needed to provide its Services?
#              Does the privacy policy affirm that Personal Data is retained for legitimate business purposes such as resolving disputes?
#              Does the privacy policy affirm that Personal Data is retained for safety and security reasons?
#              Does the privacy policy affirm that Personal Data is retained to comply with legal obligations?
#              Does the privacy policy affirm that the duration of data retention depends on the purpose for processing the data?
#              Does the privacy policy affirm that the duration of data retention depends on the amount of the information?
#              Does the privacy policy affirm that the duration of data retention depends on the nature of the information?
#              Does the privacy policy affirm that the duration of data retention depends on the sensitivity of the information?
#              Does the privacy policy affirm that the duration of data retention depends on the potential risk of harm from unauthorized use or disclosure?
#              Does the privacy policy affirm that the duration of data retention depends on applicable legal requirements?
#              Does the privacy policy affirm that the length of time data is retained can depend on user settings?
#              Does the privacy policy affirm that temporary chats will not appear in the user's history?
#              Does the privacy policy affirm that temporary chats are retained for up to 30 days for safety purposes?
#              Does the privacy policy affirm that the provided supplemental disclosures apply specifically to residents of Canada?
#              Does the privacy policy affirm that the supplemental disclosures should be read in conjunction with the rest of the privacy policy?
#              Does the privacy policy affirm that if a conflict arises between the main policy and the supplemental disclosures, the supplemental disclosures prevail for residents of Canada?
#              Does the privacy policy affirm that expressly consenting to the policy confirms the user has read and understood the policy?
#              Does the privacy policy affirm that the company relies on lawful bases other than consent where available?
#              Does the privacy policy affirm that personal data is only collected, used, or disclosed with consent unless otherwise permitted or required by law?
#              Does the privacy policy affirm that user consent may be given expressly?
#              Does the privacy policy affirm that user consent may be implied depending on the circumstances and sensitivity of information?
#              Does the privacy policy affirm that users may withdraw consent at any time, subject to legal or contractual restrictions?
#              Does the privacy policy affirm that providing personal data constitutes agreement to the transfer of data outside of Canada?
#              Does the privacy policy affirm that providing personal data constitutes agreement to the disclosure of data outside of Canada?
#              Does the privacy policy affirm that personal data may be transferred to the United States?
#              Does the privacy policy affirm that personal data may be transferred to countries listed on the company's subprocessor list?
#              Does the privacy policy affirm that data may be transferred to jurisdictions where data protection laws are less stringent than the user's jurisdiction?
#              Does the privacy policy affirm that the company may disclose personal data in foreign jurisdictions in response to legal processes?
#              Does the privacy policy affirm that the company may disclose personal data in foreign jurisdictions where good faith belief suggests disclosure is required or permitted by law?
#              Does the privacy policy affirm that users may contact the company via email for questions regarding personal data processing?
#              Does the privacy policy affirm that users may contact the company via email to exercise their rights?
#              Does the privacy policy affirm that for users in the European Economic Area (EEA), UK, or Switzerland, the data controller is the company's Irish entity?
#              Does the privacy policy affirm that for users outside the European Region, the data controller is a specific entity of the company?
#              Does the privacy policy affirm that users can contact the company via a physical address in the United States?
#              Does the privacy policy affirm that users can contact the company via a physical address in Ireland?
#              Does the privacy policy affirm that users can contact the company for privacy inquiries via email?
#              Does the privacy policy affirm that users can contact the company's Data Protection Officer via email?
#              Does the privacy policy affirm that users have the right to lodge a complaint with the supervisory authority in the place where they live?
#              Does the privacy policy affirm that users have the right to lodge a complaint with the supervisory authority in the place where they work?
#              Does the privacy policy affirm that users living or working in the UK have the right to lodge a complaint with the UK Information Commissioner’s Office?
#              Does the privacy policy affirm that users living in Brazil have the right to lodge a complaint with the Brazilian Data Protection Authority?
#              Does the privacy policy affirm that users living in Australia have the right to lodge a complaint with the Office of the Australian Information Commissioner?
#              Does the privacy policy affirm that Personal Data is used to provide the company's services?
#              Does the privacy policy affirm that Personal Data is used to analyze the company's services?
#              Does the privacy policy affirm that Personal Data is used to maintain the company's services?
#              Does the privacy policy affirm that Personal Data is used to improve the company's services?
#              Does the privacy policy affirm that Personal Data is used to develop the company's services?
#              Does the privacy policy affirm that Personal Data is used to conduct research?
#              Does the privacy policy affirm that Personal Data is used to communicate with the user?
#              Does the privacy policy affirm that Personal Data is used to send information about services and events?
#              Does the privacy policy affirm that Personal Data is used to prevent fraud?
#              Does the privacy policy affirm that Personal Data is used to prevent illegal activity?
#              Does the privacy policy affirm that Personal Data is used to prevent misuse of the company's services?
#              Does the privacy policy affirm that Personal Data is used to protect the security of the company's systems and services?
#              Does the privacy policy affirm that Personal Data is used to comply with legal obligations?
#              Does the privacy policy affirm that Personal Data is used to protect the rights, privacy, safety, or property of users?
#              Does the privacy policy affirm that Personal Data is used to protect the rights, privacy, safety, or property of the company?
#              Does the privacy policy affirm that Personal Data is used to protect the rights, privacy, safety, or property of third parties?
#              Does the privacy policy affirm that the company may aggregate Personal Data?
#              Does the privacy policy affirm that the company may de-identify Personal Data so it no longer identifies the user?
#              Does the privacy policy affirm that aggregated or de-identified data may be used for analysis, service improvement, and research?
#              Does the privacy policy affirm that the company will maintain de-identified information in de-identified form?
#              Does the privacy policy affirm that the company will not attempt to re-identify de-identified information unless required by law?
#              Does the privacy policy affirm that user-provided Content may be used to improve the services?
#              Does the privacy policy affirm that user-provided Content may be used to train the company's models?
#              Does the privacy policy affirm that users can opt out of having their Content used to train the company's models?
#              Does the privacy policy affirm that the company collects identifiers such as names when a user signs up for an account?
#              Does the privacy policy affirm that the company collects email addresses when a user signs up for an account?
#              Does the privacy policy affirm that the company collects phone numbers when a user signs up for an account?
#              Does the privacy policy affirm that the company collects identifiers when a user signs up to receive information on the services?
#              Does the privacy policy affirm that the company may collect or generate indirect identifiers?
#              Does the privacy policy affirm that the company collects payment information if a user chooses to purchase access to products and services?
#              Does the privacy policy affirm that users can interact with the services via chat sessions?
#              Does the privacy policy affirm that users can interact with the services via coding sessions?
#              Does the privacy policy affirm that users can interact with the services via agentic sessions?
#              Does the privacy policy affirm that interactions with the service include third-party applications users choose to integrate?
#              Does the privacy policy affirm that the company collects personal data if it is included in user Inputs?
#              Does the privacy policy affirm that the company collects information regarding external content referenced in user Inputs?
#              Does the privacy policy affirm that personal data included in Inputs may be reproduced in Outputs?
#              Does the privacy policy affirm that user feedback includes ideas and suggestions for improvement?
#              Does the privacy policy affirm that user feedback includes rating an Output in response to an Input?
#              Does the privacy policy affirm that the company stores the entire related conversation as part of Feedback if a user rates an Output?
#              Does the privacy policy affirm that the company collects the user's name when they communicate with the company?
#              Does the privacy policy affirm that the company collects contact information when users communicate with the company?
#              Does the privacy policy affirm that the company collects the contents of messages sent by users?
#              Does the privacy policy affirm that the company collects information from communications made via the chatbot on the Help site?
#              Does the privacy policy affirm that the company may disclose Personal Data to vendors and service providers to assist with business operations needs?
#              Does the privacy policy affirm that the company may disclose Personal Data to providers of hosting services?
#              Does the privacy policy affirm that the company may disclose Personal Data to customer service vendors?
#              Does the privacy policy affirm that the company may disclose Personal Data to cloud services?
#              Does the privacy policy affirm that the company may disclose Personal Data to content delivery services?
#              Does the privacy policy affirm that the company may disclose Personal Data to support and safety monitoring services?
#              Does the privacy policy affirm that the company may disclose Personal Data to email communication software providers?
#              Does the privacy policy affirm that the company may disclose Personal Data to web analytics services?
#              Does the privacy policy affirm that the company may disclose Personal Data to payment and transaction processors?
#              Does the privacy policy affirm that vendors and service providers process Personal Data only to perform their duties pursuant to the company's instructions?
#              Does the privacy policy affirm that Personal Data may be disclosed in the diligence process regarding strategic transactions or reorganizations?
#              Does the privacy policy affirm that Personal Data may be transferred to a successor or affiliate as part of a business transaction?
#              Does the privacy policy affirm that the company may share Personal Data with government authorities or industry peers if required to comply with a legal obligation?
#              Does the privacy policy affirm that the company may share Personal Data in the good faith belief that such action is necessary to comply with a legal obligation?
#              Does the privacy policy affirm that the company may share Personal Data to protect and defend its rights or property?
#              Does the privacy policy affirm that the company may share Personal Data if it determines there is a violation of its terms, policies, or the law?
#              Does the privacy policy affirm that the company may share Personal Data to detect or prevent fraud or other illegal activity?
#              Does the privacy policy affirm that the company may share Personal Data to protect the safety and security of its products, employees, users, or the public?
#              Does the privacy policy affirm that the company may share Personal Data to protect against legal liability?
#              Does the privacy policy affirm that the company may disclose Personal Data to its affiliates?
#              Does the privacy policy affirm that the company's affiliates may use Personal Data in a manner consistent with the privacy policy?
#              Does the privacy policy affirm that administrators of enterprise or business accounts may access and control a user's account?
#              Does the privacy policy affirm that administrators of enterprise or business accounts may access a user's Content?
#              Does the privacy policy affirm that if a user creates an account using an email address belonging to an employer, the company may share the fact that the user has an account with that employer?
#              Does the privacy policy affirm that if a user creates an account using an email address belonging to an employer, the company may share account information with the employer to enable the user to be added to a business account?
#              Does the privacy policy affirm that certain features allow users to interact or share information with other users?
#              Does the privacy policy affirm that users can send information to third-party applications via custom actions or web searches?
#              Does the privacy policy affirm that information users share with third parties is governed by those third parties' terms and privacy policies?
#              Does the privacy policy affirm that users have the statutory right to access their Personal Data?
#              Does the privacy policy affirm that users have the statutory right to access information relating to how their Personal Data is processed?
#              Does the privacy policy affirm that users have the statutory right to delete their Personal Data from the company's records?
#              Does the privacy policy affirm that users have the statutory right to rectify or update their Personal Data?
#              Does the privacy policy affirm that users have the statutory right to transfer their Personal Data to a third party?
#              Does the privacy policy affirm that users have the statutory right to restrict how the company processes their Personal Data?
#              Does the privacy policy affirm that users have the statutory right to withdraw consent at any time where consent is the legal basis for processing?
#              Does the privacy policy affirm that users have the statutory right to lodge a complaint with their local data protection authority?
#              Does the privacy policy affirm that users have the right to object to the processing of their Personal Data for direct marketing at any time?
#              Does the privacy policy affirm that users have the right to object to the processing of their Personal Data when the processing is based on legitimate interests?
#              Does the privacy policy affirm that users can exercise some of their rights through their account with the company?
#              Does the privacy policy affirm that users unable to exercise rights through their account can submit requests via a specific web portal?
#              Does the privacy policy affirm that users unable to exercise rights through their account can submit requests via email?
#              Does the privacy policy affirm that the data protection authority in Ireland is the company's lead supervisory authority?
#              Does the privacy policy affirm that users can reach out to the data protection authority in the UK for unresolved complaints relating to the UK?
#              Does the privacy policy affirm that users can reach out to the data protection authority in Switzerland for unresolved complaints relating to Switzerland?
#              Does the privacy policy affirm that the company's services generate responses by predicting the words most likely to appear next?
#              Does the privacy policy affirm that words predicted by the models may not always be the most factually accurate?
#              Does the privacy policy affirm that users should not rely on the factual accuracy of output from the company's models?
#              Does the privacy policy affirm that users can submit requests to correct or remove factually inaccurate information about themselves found in model output?
#              Does the privacy policy affirm that requests regarding inaccurate model output are considered based on applicable law?
#              Does the privacy policy affirm that requests regarding inaccurate model output are considered based on the technical capabilities of the models?
#              Does the privacy policy affirm that a separate notice is available regarding rights for data collected from the internet to train models?
#              Does the privacy policy affirm that the company is the controller responsible for processing Personal Data of users living in the European Economic Area (EEA)?
#              Does the privacy policy affirm that the company is the controller responsible for processing Personal Data of users living in Switzerland?
#              Does the privacy policy affirm that the company is the controller responsible for processing Personal Data of users living in the UK?
#              Does the privacy policy affirm that the company collects the user's name when an account is created?
#              Does the privacy policy affirm that the company collects contact information when an account is created?
#              Does the privacy policy affirm that the company collects account credentials when an account is created?
#              Does the privacy policy affirm that the company collects the user's date of birth when an account is created?
#              Does the privacy policy affirm that the company collects payment information when an account is created?
#              Does the privacy policy affirm that the company collects transaction history when an account is created?
#              Does the privacy policy affirm that the company collects Personal Data included in the user's prompts or input to the Services?
#              Does the privacy policy affirm that the company collects files uploaded by the user?
#              Does the privacy policy affirm that the company collects images uploaded by the user?
#              Does the privacy policy affirm that the company collects audio uploaded by the user?
#              Does the privacy policy affirm that the company collects the user's name if they communicate via email or social media pages?
#              Does the privacy policy affirm that the company collects contact information if the user communicates via email or social media pages?
#              Does the privacy policy affirm that the company collects the contents of messages sent by the user via communication channels?
#              Does the privacy policy affirm that the company collects information when users participate in events?
#              Does the privacy policy affirm that the company collects information when users participate in surveys?
#              Does the privacy policy affirm that the company collects information provided to establish a user's identity or age?
#              Does the privacy policy affirm that the company collects the user's Internet Protocol (IP) address as part of Log Data?
#              Does the privacy policy affirm that the company collects browser type and settings as part of Log Data?
#              Does the privacy policy affirm that the company collects the date and time of requests as part of Log Data?
#              Does the privacy policy affirm that the company collects data on how users interact with the Services as part of Log Data?
#              Does the privacy policy affirm that the company collects information about the types of content the user views or engages with?
#              Does the privacy policy affirm that the company collects information about the features the user uses?
#              Does the privacy policy affirm that the company collects information about the actions the user takes?
#              Does the privacy policy affirm that the company collects the user's time zone?
#              Does the privacy policy affirm that the company collects the user's country?
#              Does the privacy policy affirm that the company collects the dates and times of access?
#              Does the privacy policy affirm that the company collects the user agent and version?
#              Does the privacy policy affirm that the company collects the type of computer or mobile device used?
#              Does the privacy policy affirm that the company collects information about the user's computer connection?
#              Does the privacy policy affirm that the company collects the name of the device used to access the Services?
#              Does the privacy policy affirm that the company collects the operating system of the device used to access the Services?
#              Does the privacy policy affirm that the company collects device identifiers?
#              Does the privacy policy affirm that the company determines the general area from which a device accesses the Services based on the IP address?
#              Does the privacy policy affirm that general location information is used for security reasons, such as detecting unusual login activity?
#              Does the privacy policy affirm that general location information is used to provide more accurate responses?
#              Does the privacy policy affirm that some Services allow users to provide precise location information, such as GPS data?
#              Does the privacy policy affirm that the company uses cookies and similar technologies to operate and administer the Services?
#              Does the privacy policy affirm that the company uses cookies to improve the user experience?
#              Does the privacy policy affirm that the company may store information via cookies for users who do not create an account?
#              Does the privacy policy affirm that the company receives information from security partners to protect against fraud, abuse, and security threats?
#              Does the privacy policy affirm that the company receives information from marketing vendors about potential customers?
#              Does the privacy policy affirm that the company collects publicly available information from the internet to develop the models powering its Services?
#              Does the privacy policy affirm that user rights regarding personal data depend on their country of residence?
#              Does the privacy policy affirm that user rights regarding personal data are subject to limitations?
#              Does the privacy policy affirm that the process for actioning requests regarding the company's training dataset is complex?
#              Does the privacy policy affirm that the company may decline a request if there is a lawful reason to do so?
#              Does the privacy policy affirm that users can submit rights requests by emailing the company?
#              Does the privacy policy affirm that the company may verify requests by asking for information to confirm the user's identity?
#              Does the privacy policy affirm that users have the right to appeal denied requests by emailing the company?
#              Does the privacy policy affirm that the company will not discriminate against users for exercising their privacy rights?
#              Does the privacy policy affirm that users have the right to know the categories of personal data processed about them?
#              Does the privacy policy affirm that users have the right to know the categories of sources from which their data is collected?
#              Does the privacy policy affirm that users have the right to know the business or commercial purposes for collecting their data?
#              Does the privacy policy affirm that users have the right to know the categories of third parties to whom their data is disclosed?
#              Does the privacy policy affirm that users have the right to request a copy of the personal data processed about them?
#              Does the privacy policy affirm that users have the right to port their information in certain cases?
#              Does the privacy policy affirm that users have the right to request the deletion of personal data collected during the use of the Services?
#              Does the privacy policy affirm that users can delete individual conversations?
#              Does the privacy policy affirm that deleted individual conversations are removed immediately from conversation history?
#              Does the privacy policy affirm that deleted individual conversations are automatically deleted from the back-end within 30 days?
#              Does the privacy policy affirm that users have the right to request the correction of inaccurate personal data?
#              Does the privacy policy affirm that the company cannot guarantee the factual accuracy of Outputs?
#              Does the privacy policy affirm that the company will make a reasonable effort to correct factually inaccurate personal data in Outputs upon request?
#              Does the privacy policy affirm that correcting inaccurate information in Outputs may not always be possible due to the technical complexity of large language models?
#              Does the privacy policy affirm that users have the right to object to the processing of their personal data?
#              Does the privacy policy affirm that users have the right to object to profiling conducted on grounds of public or legitimate interest?
#              Does the privacy policy affirm that valid objections will stop data processing unless the company demonstrates compelling legitimate grounds that override the user's interests?
#              Does the privacy policy affirm that valid objections will stop data processing unless the processing is necessary for legal claims?
#              Does the privacy policy affirm that users can object to direct marketing messages via an unsubscribe link?
#              Does the privacy policy affirm that users have the right to restrict processing of their personal data in certain circumstances?
#              Does the privacy policy affirm that users have the right to withdraw consent where processing is based on consent?
#              Does the privacy policy affirm that the withdrawal of consent does not affect the lawfulness of processing that occurred before the withdrawal?
#              Does the privacy policy affirm that the company does not engage in decision-making based solely on automated processing that produces a legal effect?
#              Does the privacy policy affirm that the company does not engage in decision-making based solely on automated processing that significantly affects the user?
# ...
#              Does the privacy policy affirm that personal data may be shared with service providers for the purpose of providing services to the user?
#              Does the privacy policy affirm that personal data will be disclosed if the company is involved in a merger?
#              Does the privacy policy affirm that personal data will be disclosed if the company is involved in a bankruptcy?
#              Does the privacy policy affirm that personal data will be disclosed during corporate transactions involving the transfer of business assets?
#              Does the privacy policy affirm that the company's services may involve integrations with websites managed by third parties?
#              Does the privacy policy affirm that the company's services may direct users to apps managed by third parties?
#              Does the privacy policy affirm that interacting with third-party integrations involves providing information directly to that third party?
#              Does the privacy policy affirm that information provided directly to third-party integrations is not provided to the company?
#              Does the privacy policy affirm that information provided to third parties is subject to the third party's privacy policy?
#              Does the privacy policy affirm that accessed third-party services can collect personal data about the user?
#              Does the privacy policy affirm that third-party services may collect information about the user's activity on the company's services?
#              Does the privacy policy affirm that linking to a third-party site does not constitute an endorsement by the company?
#              Does the privacy policy affirm that linking to a third-party service does not mean the company speaks for that third party?
#              Does the privacy policy affirm that the company may disclose personal data to governmental regulatory authorities as required by law?
#              Does the privacy policy affirm that the company may disclose personal data for tax purposes?
#              Does the privacy policy affirm that the company may disclose personal data for accounting purposes?
#              Does the privacy policy affirm that the company may disclose personal data in response to requests from governmental regulatory authorities?
#              Does the privacy policy affirm that the company may disclose personal data to assist in investigations by governmental regulatory authorities?
#              Does the privacy policy affirm that personal data may be disclosed to third parties in connection with litigation?
#              Does the privacy policy affirm that personal data may be disclosed to third parties in connection with claims or disputes?
#              Does the privacy policy affirm that personal data may be disclosed if necessary to protect the health and safety of the user or any other person?
#              Does the privacy policy affirm that personal data may be disclosed to protect against fraud?
#              Does the privacy policy affirm that personal data may be disclosed to protect against credit risk?
#              Does the privacy policy affirm that personal data may be disclosed to enforce the company's legal rights?
#              Does the privacy policy affirm that personal data may be disclosed to enforce the legal rights of others?
#              Does the privacy policy affirm that personal data may be disclosed to enforce contractual commitments made by the user?
#              Does the privacy policy affirm that the company will disclose personal data when an individual gives permission?
#              Does the privacy policy affirm that the company will disclose personal data when an individual directs the company to disclose such information?
#              Does the privacy policy affirm that the company engages third parties to help process personal data?
#              Does the privacy policy affirm that information about engaged third parties is available on the company's Subprocessor List?
#              Does the privacy policy affirm that the company acts as a data processor with respect to personal data received when users utilize the company's commercial services?
#              Does the privacy policy affirm that technical data is received automatically when the user uses the services?
#              Does the privacy policy affirm that the user's device or browser sends information about when and how services are installed, accessed, or used?
#              Does the privacy policy affirm that the company collects information about the user's device type?
#              Does the privacy policy affirm that the company collects operating system information?
#              Does the privacy policy affirm that the company collects browser information?
#              Does the privacy policy affirm that the company collects web page referrers?
#              Does the privacy policy affirm that the company collects mobile network information?
#              Does the privacy policy affirm that the company collects connection information?
#              Does the privacy policy affirm that the company collects information about the user's mobile operator or internet service provider (ISP)?
#              Does the privacy policy affirm that the company collects time zone settings?
#              Does the privacy policy affirm that the company collects IP addresses?
#              Does the privacy policy affirm that device location information is derived from IP addresses?
#              Does the privacy policy affirm that the company collects advertising identifiers?
#              Does the privacy policy affirm that the company collects probabilistic identifiers?
#              Does the privacy policy affirm that the company collects unique personal or online identifiers?
#              Does the privacy policy affirm that the company collects device location data?
#              Does the privacy policy affirm that the company collects the dates and times of access to the services?
#              Does the privacy policy affirm that the company collects browsing history?
#              Does the privacy policy affirm that the company collects search information?
#              Does the privacy policy affirm that the company collects information about the links users click?
#              Does the privacy policy affirm that the company collects information about the pages users view?
#              Does the privacy policy affirm that the company collects information about the technology on the devices used to access the services?
#              Does the privacy policy affirm that the company collects log files regarding how services are performing?
#              Does the privacy policy affirm that information about an error is collected if the user or device experiences one?
#              Does the privacy policy affirm that the company collects the time an error occurred?
#              Does the privacy policy affirm that the company collects information about the feature being used when an error occurred?
#              Does the privacy policy affirm that the company collects the state of the application when an error occurred?
#              Does the privacy policy affirm that the company collects any communications or content provided at the time an error occurred?
#              Does the privacy policy affirm that the company and its service providers use cookies, scripts, or similar technologies?
#              Does the privacy policy affirm that cookies are used to manage the services?
#              Does the privacy policy affirm that cookies are used to collect information about the user and their use of the services?
#              Does the privacy policy affirm that cookies are used to recognize the user?
#              Does the privacy policy affirm that cookies are used to customize or personalize the user's experience?
#              Does the privacy policy affirm that cookies are used to market additional products or services to the user?
#              Does the privacy policy affirm that cookies are used to analyze the use of services to make them safer and more useful?
#              Does the privacy policy affirm that identity and contact data are processed to provide and maintain products governed by the Terms of Service?
#              Does the privacy policy affirm that payment information is processed to provide and maintain products governed by the Terms of Service?
#              Does the privacy policy affirm that inputs and outputs are processed to provide and maintain products governed by the Terms of Service?
#              Does the privacy policy affirm that the performance of a contract is the legal basis for processing data to provide services governed by the Terms of Service?
#              Does the privacy policy affirm that consent is the legal basis for processing precise device location to enhance platform functionality?
#              Does the privacy policy affirm that legitimate interests are a legal basis for expanding product features to enhance user experience?
#              Does the privacy policy affirm that technical information is processed to communicate with the user and promote services?
#              Does the privacy policy affirm that the company processes contact information to send technical announcements based on the necessity to perform a contract?
#              Does the privacy policy affirm that the company processes contact information for marketing communications based on user consent?
#              Does the privacy policy affirm that legitimate interests are a legal basis for sending direct marketing?
#              Does the privacy policy affirm that identity and contact data are processed to create and administer the user's account?
#              Does the privacy policy affirm that payment information is processed to facilitate payments for products and services?
#              Does the privacy policy affirm that inputs and outputs are processed to prevent and investigate fraud and abuse?
#              Does the privacy policy affirm that technical information is processed to prevent unlawful activity or unauthorized access to systems?
#              Does the privacy policy affirm that the company processes data based on legitimate interests to protect the business from illegal activities?
#              Does the privacy policy affirm that inputs and outputs are processed to investigate and resolve disputes?
#              Does the privacy policy affirm that the company processes data based on legitimate interests to resolve customer complaints and improve user satisfaction?
#              Does the privacy policy affirm that technical information is processed to investigate and resolve security issues?
#              Does the privacy policy affirm that the company has a legal obligation to provide adequate security safeguards?
#              Does the privacy policy affirm that technical information is processed to debug and repair errors that impair existing functionality?
#              Does the privacy policy affirm that inputs and outputs are processed to improve services and conduct research excluding model training?
#              Does the privacy policy affirm that feedback is processed to improve services and conduct research including model training?
#              Does the privacy policy affirm that data provided through the Development Partner Program is used to improve services and conduct research including model training?
#              Does the privacy policy affirm that consent is the legal basis for processing user feedback for model training research?
#              Does the privacy policy affirm that legitimate interests are a legal basis for research investigating the safety and societal impact of AI models?
#              Does the privacy policy affirm that inputs and outputs are processed to enforce the Terms of Service and Usage Policy?
#              Does the privacy policy affirm that legitimate interests are a legal basis for processing data to enforce rules and policies governing the use of services?
#              Does the privacy policy affirm that personal data is used to provide products and services related to the user's account?
#              Does the privacy policy affirm that personal data is used to maintain products and services related to the user's account?
#              Does the privacy policy affirm that personal data is used to facilitate optional services that enhance platform functionality?
#              Does the privacy policy affirm that personal data is used to facilitate optional features that enhance user experience?
#              Does the privacy policy affirm that personal data is used to send information about the company's services?
#              Does the privacy policy affirm that personal data is used to send information about events?
#              Does the privacy policy affirm that personal data is used to create the user's account?
#              Does the privacy policy affirm that personal data is used to administer the user's account?
#              Does the privacy policy affirm that personal data is used to facilitate payments for products and services provided by the company?
#              Does the privacy policy affirm that personal data is used to investigate abuse?
#              Does the privacy policy affirm that personal data is used to investigate violations of the Usage Policy?
#              Does the privacy policy affirm that personal data is used to prevent unlawful or criminal activity?
#              Does the privacy policy affirm that personal data is used to prevent unauthorized access to personal data?
#              Does the privacy policy affirm that personal data is used to prevent unauthorized access to the company's systems and networks?
#              Does the privacy policy affirm that personal data is used to protect the rights of the company and others?
#              Does the privacy policy affirm that personal data is used to meet legal, governmental, and institutional policy obligations?
#              Does the privacy policy affirm that personal data is used to investigate disputes?
#              Does the privacy policy affirm that personal data is used to resolve disputes?
#              Does the privacy policy affirm that personal data is used to investigate security issues?
#              Does the privacy policy affirm that personal data is used to resolve security issues?
#              Does the privacy policy affirm that personal data is used to debug errors?
#              Does the privacy policy affirm that personal data is used to repair errors that impair existing functionality?
#              Does the privacy policy affirm that personal data is used to train the company's models?
#              Does the privacy policy affirm that personal data is used to enforce the Terms of Service?
#              Does the privacy policy affirm that user Inputs and Outputs may be used to train the company's models?
#              Does the privacy policy affirm that user Inputs and Outputs may be used to improve the company's services?
#              Does the privacy policy affirm that users can opt out of having their Inputs and Outputs used for training through account settings?
#              Does the privacy policy affirm that Inputs and Outputs are used for model improvement despite an opt-out if conversations are flagged for safety review?
#              Does the privacy policy affirm that flagged conversations are used to improve the detection of harmful content?
#              Does the privacy policy affirm that flagged conversations are used to enforce company policies?
#              Does the privacy policy affirm that flagged conversations are used to advance AI safety research?
#              Does the privacy policy affirm that Inputs and Outputs are used for model improvement despite an opt-out if the user explicitly reports the materials to the company?
# --------------------------------------------------------------------------------

# %%
import numpy as np
import pandas as pd
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import cdist, mahalanobis
from sklearn.cluster import AgglomerativeClustering
from itertools import combinations

# =========================================================
# 1. DATA PREPARATION (Updated to return vectors/precision)
# =========================================================


def prepare_model_artifacts(raw_vector_list, name="Model"):
	"""
	Returns dictionary containing:
	- 'dist_matrix': N x N pairwise distances
	- 'vectors': N x 256 normalized vectors
	- 'precision': 256 x 256 inverse covariance matrix
	"""
	print(f"Processing {name}...")

	# 1. Truncate & Normalize
	data = np.array(raw_vector_list)
	data_trunc = data[:, :256]
	norms = np.linalg.norm(data_trunc, axis=1, keepdims=True)
	cleaned_vectors = data_trunc / (norms + 1e-10)

	# 2. Ledoit-Wolf
	lw = LedoitWolf()
	lw.fit(cleaned_vectors)
	precision_matrix = lw.precision_

	# 3. Distance Matrix
	dist_matrix = cdist(
		cleaned_vectors, cleaned_vectors, metric="mahalanobis", VI=precision_matrix
	)

	return {
		"dist_matrix": dist_matrix,
		"vectors": cleaned_vectors,
		"precision": precision_matrix,
	}


# --- LOAD DATA ---
# Assuming 'qdata' is available
data_set = qdata
strings = list(data_set.keys())

raw_vectors_A = [data_set[s]["embedding_vector"] for s in strings]
raw_vectors_B = [data_set[s]["retrieval_embedding_vector"] for s in strings]

# --- PROCESS ARTIFACTS ---
# We store everything in a dictionary to keep it organized
Model_A = prepare_model_artifacts(raw_vectors_A, "Model A (Statement)")
Model_B = prepare_model_artifacts(raw_vectors_B, "Model B (Question)")
import numpy as np
import pandas as pd
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import cdist, mahalanobis
from sklearn.cluster import AgglomerativeClustering
from itertools import combinations
from collections import defaultdict

# =========================================================
# 1. HELPER FUNCTIONS
# =========================================================


def get_pairs_from_labels(labels):
	"""Converts cluster labels into a Set of unique pairs (indices)."""
	df = pd.DataFrame({"label": labels, "id": range(len(labels))})
	pairs = set()
	for label, group in df.groupby("label"):
		indices = group["id"].tolist()
		if len(indices) > 1:
			for p in combinations(sorted(indices), 2):
				pairs.add(p)
	return pairs


def get_clustering_pairs_and_labels(dist_matrix, threshold):
	"""Runs clustering and returns both the pair set and the labels array."""
	model = AgglomerativeClustering(
		n_clusters=None,
		distance_threshold=threshold,
		metric="precomputed",
		linkage="complete",
	)
	labels = model.fit_predict(dist_matrix)
	return get_pairs_from_labels(labels), labels


def calculate_n_true(labels_array, target_pairs):
	"""Calculates the number of unique clusters containing the elements of target_pairs."""
	if not target_pairs or labels_array is None:
		return 0

	# Identify all indices involved in the platinum pairs
	involved_indices = set(idx for pair in target_pairs for idx in pair)

	# Get the unique cluster labels associated with those indices
	labels_of_interest = set(
		labels_array[idx] for idx in involved_indices if idx < len(labels_array)
	)

	# If P_true is empty, N_true must be zero.
	if not involved_indices:
		return 0

	return len(labels_of_interest)


# =========================================================
# 2. STAGE 1: CONSENSUS TUNING (Setup - Requires Model_A, Model_B, strings)
# =========================================================

# --- Assuming Model_A, Model_B, and strings are already populated from the preparation step ---

print("\n--- Phase 1: Grid Search for Consensus (Tau) ---")

# tau_range = np.arange(5.0, 18.0, 0.1)
# --- Dynamic Range Calculation (Adhering to Absolute Min/Max) ---

# Combine the off-diagonal elements of both distance matrices
dist_A_off = Model_A["dist_matrix"][np.triu_indices_from(Model_A["dist_matrix"], k=1)]
dist_B_off = Model_B["dist_matrix"][np.triu_indices_from(Model_B["dist_matrix"], k=1)]
all_dists = np.concatenate([dist_A_off, dist_B_off])

# Calculate the bounds
D_min_min = np.min(all_dists)
D_max_max = np.max(all_dists)

# Define search range: Start slightly below min, end slightly above max
# This ensures we capture the boundary points exactly.
SEARCH_STEP = 0.5	# Retain the fine step size for accuracy

# TAU_SEARCH_START = max(D_min_min - SEARCH_STEP, 0.0)
# TAU_SEARCH_END = D_max_max + SEARCH_STEP

TAU_SEARCH_START = max(D_min_min, 0.0)
TAU_SEARCH_END = D_max_max

tau_range = np.arange(TAU_SEARCH_START, TAU_SEARCH_END, SEARCH_STEP)
t_range = np.arange(TAU_SEARCH_START, TAU_SEARCH_END, SEARCH_STEP)

print(
	f"Search Range Defined: [{TAU_SEARCH_START:.2f} to {TAU_SEARCH_END:.2f}] (Step: {SEARCH_STEP})"
)
best_jaccard = -1
P_true = set()
labels_A_star = None
labels_B_star = None

# Cache structure: {tau: (pair_set, labels_array)}
cache_A = {}
cache_B = {}

print(f"Pre-computing clusters for {len(tau_range)} thresholds...")
for t in tau_range:
	cache_A[t] = get_clustering_pairs_and_labels(Model_A["dist_matrix"], t)
	cache_B[t] = get_clustering_pairs_and_labels(Model_B["dist_matrix"], t)
TAU_A = 0
TAU_B = 0

# Run grid search
for t_A in tau_range:
	pairs_A, labels_A = cache_A[t_A]
	for t_B in tau_range:
		pairs_B, labels_B = cache_B[t_B]

		intersection = pairs_A.intersection(pairs_B)
		union = pairs_A.union(pairs_B)

		if len(union) > 0:
			jaccard = len(intersection) / len(union)
			if jaccard > best_jaccard:

				best_jaccard = jaccard
				P_true = intersection
				labels_A_star = labels_A
				labels_B_star = labels_B
				TAU_A = t_A
				TAU_B = t_B

print(f"tau a:{TAU_A}, tau b:{TAU_B}")

# Calculate N_target
N_A_true = calculate_n_true(labels_A_star, P_true)
N_B_true = calculate_n_true(labels_B_star, P_true)
N_target = (N_A_true + N_B_true) / 2

print(f"\nConsensus Structure Found:")
print(f"Platinum Pairs Identified: {len(P_true)}")
print(f"N_target: {N_target:.1f} (Avg of A={N_A_true}, B={N_B_true})")

# =========================================================
# 3. TUNING TARGET THRESHOLDS (t)
# =========================================================

print("\n--- Phase 2: Tuning Thresholds to Target N_target ---")


def tune_threshold_by_group_count(model_data, N_target, model_name):
	best_t = 0
	min_error = float("inf")
	best_f1 = -1

	# t_range = np.arange(5.0, 20.0, 0.1)

	for t in t_range:
		current_pairs, current_labels = get_clustering_pairs_and_labels(
			model_data["dist_matrix"], t
		)

		# 1. Calculate primary error (Group Count Error)
		N_predicted = calculate_n_true(current_labels, P_true)
		group_error = abs(N_predicted - N_target)

		# 2. Calculate secondary metric (F1 score)
		tp = len(current_pairs.intersection(P_true))
		fp = len(current_pairs - P_true)
		fn = len(P_true - current_pairs)

		if tp > 0:
			precision = tp / (tp + fp)
			recall = tp / (tp + fn)
			f1 = 2 * (precision * recall) / (precision + recall)
		else:
			f1 = 0

		# Optimization Logic: (Minimize error, maximize F1 as tie-breaker)
		if group_error < min_error:
			min_error = group_error
			best_f1 = f1
			best_t = t
		elif group_error == min_error and f1 > best_f1:
			best_f1 = f1
			best_t = t

	print(
		f"[{model_name}] Optimal t: {best_t:.1f} | Group Error: {min_error:.1f} | F1: {best_f1:.4f}"
	)
	return best_t


optimal_t_A = tune_threshold_by_group_count(Model_A, N_target, "Model A")
optimal_t_B = tune_threshold_by_group_count(Model_B, N_target, "Model B")

print(f"\nFinal Calibrated Thresholds:")
print(f"Model A (Statement): {optimal_t_A:.2f}")
print(f"Model B (Question):  {optimal_t_B:.2f}")

# =========================================================
# 4. FINAL VISUALIZATION (Printing Groups)
# =========================================================


def print_final_clusters(model_data, threshold, string_list, title):
	print(f"\n{'='*80}")
	print(f"FINAL OUTPUT: {title} (Threshold: {threshold:.2f})")
	print(f"{'='*80}")

	# 1. Cluster using the optimized t
	cluster_model = AgglomerativeClustering(
		n_clusters=None,
		distance_threshold=threshold,
		metric="precomputed",
		linkage="complete",
	)
	labels = cluster_model.fit_predict(model_data["dist_matrix"])

	# 2. Organize and filter groups
	df = pd.DataFrame(
		{"string": string_list, "label": labels, "idx": range(len(string_list))}
	)
	groups = [g for _, g in df.groupby("label") if len(g) > 1]
	groups.sort(key=lambda x: len(x), reverse=True)

	# Calculate statistics for P_true within this final clustering
	final_pairs, _ = get_clustering_pairs_and_labels(model_data["dist_matrix"], threshold)
	tp = len(final_pairs.intersection(P_true))
	fp = len(final_pairs - P_true)

	print(f"Found {len(groups)} total significant groups.")
	print(f"P_true pairs captured: {tp} (False Positives: {fp})\n")

	# 3. Print Groups (with Centroid and Radius)
	for i, group in enumerate(groups):
		indices = group["idx"].tolist()
		cluster_strs = group["string"].tolist()

		# Centroid/Radius Logic
		vecs = model_data["vectors"][indices]
		prec = model_data["precision"]
		local_mean = np.mean(vecs, axis=0)

		distances = []
		min_dist = float("inf")
		rep_idx = -1

		for local_i, global_i in enumerate(indices):
			d = mahalanobis(model_data["vectors"][global_i], local_mean, prec)
			distances.append(d)
			if d < min_dist:
				min_dist = d
				rep_idx = local_i

		group_radius = max(distances)

		print(f"GROUP {i+1} (Size: {len(indices)}) [Radius: {group_radius:.4f}]")

		for idx, s in enumerate(cluster_strs):
			prefix = " [CENTROID] " if idx == rep_idx else "            "
			print(f"{prefix} {s}")
		print("-" * 80)


# --- EXECUTE VISUALIZATION ---
print_final_clusters(Model_A, optimal_t_A, strings, "Model A (Statement Embeddings)")
print_final_clusters(Model_B, optimal_t_B, strings, "Model B (Question Embeddings)")

import numpy as np
import pandas as pd
from scipy.spatial.distance import squareform
from scipy.stats import rankdata
from sklearn.cluster import AgglomerativeClustering

# =========================================================
# 1. EMPIRICAL PROBABILITY ESTIMATION (Non-Parametric)
# =========================================================


def get_nearest_neighbor_distances(dist_matrix):
	"""
	Extracts the distance to the nearest neighbor for every point.
	Ignores the diagonal (0).
	"""
	np.fill_diagonal(dist_matrix, float("inf"))
	min_dists = np.min(dist_matrix, axis=1)
	np.fill_diagonal(dist_matrix, 0.0)	# Restore
	return min_dists


def convert_dist_to_prob(dist_matrix, reference_dist_array):
	"""
	Converts raw distances into Probabilities (P-values) based on the
	Empirical CDF of the provided reference distribution (Nearest Neighbors).

	P(d) = (Rank of d) / (Total Count + 1)
	"""
	# We define the "Background" as the distribution of nearest neighbors.
	# Why? Because non-duplicates have large NN distances, duplicates have small ones.
	# We want to know: "Is this distance surprisingly small even for a nearest neighbor?"

	sorted_refs = np.sort(reference_dist_array)
	n = len(sorted_refs)

	# Use searchsorted to find the rank of every element in the matrix efficiently
	# This is effectively the ECDF.
	# Indices corresponding to where the values would be inserted
	ranks = np.searchsorted(sorted_refs, dist_matrix)

	# Calculate Probability (P-value)
	# P < epsilon means "This is in the bottom epsilon% of nearest neighbor distances"
	probs = (ranks + 1) / (n + 1)

	return probs


print("--- Calculating Empirical Probabilities (EVT Logic) ---")

# 1. Get the distribution of "closest things" for each model
# This forms our background distribution for "How close do things get?"
nn_dists_A = get_nearest_neighbor_distances(Model_A["dist_matrix"])
nn_dists_B = get_nearest_neighbor_distances(Model_B["dist_matrix"])

# 2. Convert the full N x N matrices to Probability Matrices
# "How likely is this pair to be this close by chance?"
Prob_A = convert_dist_to_prob(Model_A["dist_matrix"], nn_dists_A)
Prob_B = convert_dist_to_prob(Model_B["dist_matrix"], nn_dists_B)

print(f"Probabilities Calculated.")
print(
	f"Example (Model A): Dist=8.8 -> P={np.interp(8.8, np.sort(nn_dists_A), np.linspace(0,1,len(nn_dists_A))):.5f}"
)
print(
	f"Example (Model B): Dist=8.8 -> P={np.interp(8.8, np.sort(nn_dists_B), np.linspace(0,1,len(nn_dists_B))):.5f}"
)
# =========================================================
# 2. PROBABILITY FUSION (Joint Rarity)
# =========================================================

# We assume models provide independent evidence.
# We want pairs where AT LEAST ONE model thinks it's extremely rare.
# But simply multiplying P_A * P_B favors agreement.
# We want the "Max Signal" logic (Min Probability).
# Logic: If Model B says P=0.0001 and Model A says P=0.5,
# The pair IS rare in B's view. It is an outlier.

print("\n--- Fusing Probabilities (Min Rule) ---")

# We take the Minimum Probability (Maximum Surprise)
Prob_Fused = np.minimum(Prob_A, Prob_B)

# =========================================================
# 3. INFERENCE: INFERRING THE THRESHOLD
# =========================================================

print("\n--- Inferring Threshold from Platinum Pairs ---")

platinum_probs = []
for idx1, idx2 in P_true:
	p_val = Prob_Fused[idx1, idx2]
	platinum_probs.append(p_val)

PROB_THRESHOLD = 0.049019607843137254

print(f"Inferred Probability Threshold: {PROB_THRESHOLD:.6f}")

# =========================================================
# 4. CLUSTERING & REPORTING
# =========================================================

print(f"\n{'='*80}")
print(f"STAGE 2 OUTPUT: Probabilistic Outlier Model (P < {PROB_THRESHOLD:.6f})")
print(f"{'='*80}")

# We define distance for clustering as the Probability.
# Single Linkage logic (min probability) is implicitly handled by the Min-Fusion above.
# We use Complete Linkage on the Probability Matrix to form tight groups.

cluster_model = AgglomerativeClustering(
	n_clusters=None,
	distance_threshold=PROB_THRESHOLD,
	metric="precomputed",
	linkage="complete",
)

labels = cluster_model.fit_predict(Prob_Fused)

# --- VISUALIZATION ---

df = pd.DataFrame({"string": strings, "label": labels, "idx": range(len(strings))})
groups = [g for _, g in df.groupby("label") if len(g) > 1]
groups.sort(key=lambda x: len(x), reverse=True)

print(f"Found {len(groups)} significant groups.\n")

for i, group in enumerate(groups):
	indices = group["idx"].tolist()
	cluster_strs = group["string"].tolist()

	# For Centroid/Radius, we use Model B vectors (or A) as a geometric reference.
	# It's just for display purposes.
	ref_vectors = Model_B["vectors"][indices]
	ref_prec = Model_B["precision"]
	local_mean = np.mean(ref_vectors, axis=0)

	dists = []
	min_d = float("inf")
	rep_i = -1

	for loc_i, glob_i in enumerate(indices):
		d = mahalanobis(Model_B["vectors"][glob_i], local_mean, ref_prec)
		dists.append(d)
		if d < min_d:
			min_d = d
			rep_i = loc_i

	# Also print the Joint Probability of the group (min p among pairs)
	# Just to verify our logic.
	print(f"GROUP {i+1} (Size: {len(indices)}) [Radius: {max(dists):.4f}]")

	for idx, s in enumerate(cluster_strs):
		prefix = " [CENTROID] " if idx == rep_i else "            "
		print(f"{prefix} {s}")
	print("-" * 80)
# Out:
# Processing Model A (Statement)...

# %%
import pandas as pd
from scipy.spatial.distance import cdist
from sklearn.cluster import AgglomerativeClustering
import numpy as np
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import mahalanobis

data_set = qdata
strings = list(data_set.keys())

# raw_vectors = np.array(
# 	[data_set[s]["retrieval_embedding_vector"] for s in strings]
# )	# alt
raw_vectors = np.array([data_set[s]["embedding_vector"] for s in strings])


print(f"Original shape: {raw_vectors.shape}")


truncated_vectors = raw_vectors[:, :256]


norms = np.linalg.norm(truncated_vectors, axis=1, keepdims=True)

cleaned_vectors = truncated_vectors / (norms + 1e-10)

print(f"Truncated shape: {cleaned_vectors.shape}")


lw = LedoitWolf()
lw.fit(cleaned_vectors)


precision_matrix = lw.precision_
mean_vector = lw.location_

DISTANCE_THRESHOLD = 8.823086354550213	# 9.223086354550212

print(f"Computing pairwise Mahalanobis distances for {len(cleaned_vectors)} vectors...")
print(f"Using Threshold: {DISTANCE_THRESHOLD}")

dist_matrix = cdist(
	cleaned_vectors, cleaned_vectors, metric="mahalanobis", VI=precision_matrix
)
cluster_model = AgglomerativeClustering(
	n_clusters=None,
	distance_threshold=DISTANCE_THRESHOLD,
	metric="precomputed",
	linkage="complete",
)

labels = cluster_model.fit_predict(dist_matrix)


df = pd.DataFrame(
	{"string": strings, "label": labels, "vector_index": range(len(strings))}
)

all_clusters = [group for _, group in df.groupby("label")]

significant_clusters = [g for g in all_clusters if len(g) > 1]

significant_clusters.sort(key=lambda x: len(x), reverse=True)

total_groups = len(all_clusters)
trivial_count = total_groups - len(significant_clusters)

baseline_indices = {
	tuple(g["vector_index"].sort_values().tolist()) for g in significant_clusters
}

if not baseline_indices:
	print(
		"Baseline run resulted in no significant clusters (all size 1 or 0). Skipping stability check."
	)
else:
	print(
		f"\nStarting stability check against {len(baseline_indices)} baseline significant clusters."
	)

	STEP_SIZE = 0.05	# Define a reasonable step size
	MAX_ITERATIONS = 500

	t = DISTANCE_THRESHOLD
	final_stable_threshold = DISTANCE_THRESHOLD

	for i in range(MAX_ITERATIONS):
		t += STEP_SIZE

		cluster_model_t = AgglomerativeClustering(
			n_clusters=None,
			distance_threshold=t,
			metric="precomputed",
			linkage="complete",
		)

		labels_t = cluster_model_t.fit_predict(dist_matrix)

		df_t = pd.DataFrame(
			{"string": strings, "label": labels_t, "vector_index": range(len(strings))}
		)

		all_clusters_t = [group for _, group in df_t.groupby("label")]
		significant_clusters_t = [g for g in all_clusters_t if len(g) > 1]

		current_indices = {
			tuple(g["vector_index"].sort_values().tolist()) for g in significant_clusters_t
		}

		if not baseline_indices.issubset(current_indices):

			print("\n--- STABILITY BROKEN ---")
			print(f"First merge/change detected at proposed threshold t={t:.6f}")
			print(f"Maximum stable threshold found: {final_stable_threshold:.6f}")
			break

		else:
			final_stable_threshold = t
			if i % 20 == 0:
				print(
					f"Iteration {i}: Threshold {t:.6f} stable. Significant clusters found: {len(significant_clusters_t)}"
				)

	else:
		print(
			f"\nReached Max Iterations ({MAX_ITERATIONS}). Final stable threshold: {final_stable_threshold:.6f}"
		)

# %%
def getMaxStable(start_tau, model_data):

	dist_matrix = model_data["dist_matrix"]

	# --- Baseline Run ---
	base_model = AgglomerativeClustering(
		n_clusters=None,
		distance_threshold=start_tau,
		metric="precomputed",
		linkage="complete",
	)
	base_labels = base_model.fit_predict(dist_matrix)

	def get_cluster_set_and_count(labels, n_items):
		df = pd.DataFrame({"label": labels, "idx": range(n_items)})
		groups = [
			g["idx"].sort_values().tolist() for _, g in df.groupby("label") if len(g) > 1
		]
		# Return set of tuples for subset comparison, and the count
		return set(tuple(g) for g in groups), len(groups)

	baseline_indices, baseline_count = get_cluster_set_and_count(
		base_labels, len(dist_matrix)
	)

	if not baseline_indices:
		return 0

	# --- Stability Loop ---
	STEP_SIZE = SEARCH_STEP
	MAX_ITERATIONS = 500
	t = start_tau
	last_stable_count = baseline_count

	for _ in range(MAX_ITERATIONS):
		t += STEP_SIZE

		model_t = AgglomerativeClustering(
			n_clusters=None,
			distance_threshold=t,
			metric="precomputed",
			linkage="complete",
		)
		labels_t = model_t.fit_predict(dist_matrix)

		current_indices, current_count = get_cluster_set_and_count(labels_t, len(dist_matrix))

		# If baseline is not a subset of current, stability is broken
		if not baseline_indices.issubset(current_indices):
			return last_stable_count

		last_stable_count = current_count

	return last_stable_count


AV_STABLE = (getMaxStable(TAU_A, Model_A) + getMaxStable(TAU_B, Model_B)) / 2
