# %% [markdown]
# **Exclusions:**
# Exclude generic, or non-specific, or emotive affirmations that do not add substantial or verifiable information about the policy:
# ```
# Does the privacy policy affirm that the company respects user privacy?
# Does the privacy policy affirm that the company is strongly committed to keeping secure any information obtained from or about users?
# ```

# %%
from policy_analyser import AnalysisProcessor

data_source = {
	"openai": "https://openai.com/policies/privacy-policy/",
	# "anthropic": "https://www.anthropic.com/legal/privacy",
	# "perplexity": "https://www.perplexity.ai/hub/legal/privacy-policy",	# HTTPError: 403 Client Error: Forbidden for url: https://www.perplexity.ai/hub/legal/privacy-policy
	# "deepseek": "https://cdn.deepseek.com/policies/en-US/deepseek-privacy-policy.html", # Returns None
}

analyser = AnalysisProcessor(data_source, substring_mode=1)
analyser.runAnalyses(limit_iterations=4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 11
#       3 data_source = {
#       4 	"openai": "https://openai.com/policies/privacy-policy/",
#       5 	# "anthropic": "https://www.anthropic.com/legal/privacy",
#       6 	# "perplexity": "https://www.perplexity.ai/hub/legal/privacy-policy",	# HTTPError: 403 Client Error: Forbidden for url: https://www.perplexity.ai/hub/legal/privacy-policy
#       7 	# "deepseek": "https://cdn.deepseek.com/policies/en-US/deepseek-privacy-policy.html", # Returns None
#       8 }
#      10 analyser = AnalysisProcessor(data_source, substring_mode=1)
# ---> 11 analyser.runAnalyses(mode="DEBUG_QUESTION_GENERATION")
#
# File ~/AICompatibleWEB/tool/policy_analyser.py:396, in AnalysisProcessor.runAnalyses(self, mode)
#     393 chunk_embedding = chunk.pop("retreval_embedding_vector")
#     394 chunk_content = list(chunk.values())[0]
# --> 396 _question_set: str = self.model_interface.generateQuestions(chunk_content)
#     397 question_set = ast.literal_eval(_question_set)
#     398 if self.mode == "DEBUG_QUESTION_GENERATION":
#
# File ~/AICompatibleWEB/tool/question_analysis.py:65, in LLMInterface.generateQuestions(self, input_section)
#      56 			print("using debug for qs")
#      58 		prompt = f"""{ANALYSIS_PROMPT}
#      59
#      60 # Input Privacy Policy Excerpt
#    (...)     63 ```
#      64 """
# ---> 65 		resp = self.model.generateContent(
#      66 			prompt,
#      67 			config={
#      68 				"response_mime_type": "application/json",
#      69 				"response_json_schema": Affirmation_Question_Set.model_json_schema(),
#      70 			},
#      71 		)
#      73 		return resp
#
# File ~/AICompatibleWEB/tool/model_management.py:46, in GeminiModel.generateContent(self, prompt, model_name, config)
#      44 if model_name is None:
#      45 	model_name = self.DEFAULT_CHAT_MODEL
# ---> 46 response = self.client.models.generate_content(
#      47 	model=model_name, contents=prompt, config=config
#      48 )
#      49 return response.text
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/google/genai/models.py:5056, in Models.generate_content(self, model, contents, config)
#    5054 while remaining_remote_calls_afc > 0:
#    5055   i += 1
# -> 5056   response = self._generate_content(
#    5057       model=model, contents=contents, config=parsed_config
#    5058   )
#    5060   function_map = _extra_utils.get_function_map(parsed_config)
#    5061   if not function_map:
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/google/genai/models.py:3843, in Models._generate_content(self, model, contents, config)
#    3840 request_dict = _common.convert_to_dict(request_dict)
#    3841 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3843 response = self._api_client.request(
#    3844     'post', path, request_dict, http_options
#    3845 )
#    3847 if config is not None and getattr(
#    3848     config, 'should_return_http_response', None
#    3849 ):
#    3850   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1331, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1321 def request(
#    1322     self,
#    1323     http_method: str,
#    (...)   1326     http_options: Optional[HttpOptionsOrDict] = None,
#    1327 ) -> SdkHttpResponse:
#    1328   http_request = self._build_request(
#    1329       http_method, path, request_dict, http_options
#    1330   )
# -> 1331   response = self._request(http_request, http_options, stream=False)
#    1332   response_body = (
#    1333       response.response_stream[0] if response.response_stream else ''
#    1334   )
#    1335   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1167, in BaseApiClient._request(self, http_request, http_options, stream)
#    1164     retry = tenacity.Retrying(**retry_kwargs)
#    1165     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1167 return self._retry(self._request_once, http_request, stream)
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1137, in BaseApiClient._request_once(self, http_request, stream)
#    1133   return HttpResponse(
#    1134       response.headers, response if stream else [response.text]
#    1135   )
#    1136 else:
# -> 1137   response = self._httpx_client.request(
#    1138       method=http_request.method,
#    1139       url=http_request.url,
#    1140       headers=http_request.headers,
#    1141       content=data,
#    1142       timeout=http_request.timeout,
#    1143   )
#    1144   errors.APIError.raise_for_response(response)
#    1145   return HttpResponse(
#    1146       response.headers, response if stream else [response.text]
#    1147   )
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/AICompatibleWEB/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
from model_management import GeminiModel
from policy_analyser import loadQuestions, loadPolicies
import numpy as np
from google.genai import types

q_dict = loadQuestions()
questions = list(q_dict.keys())[:20]
m = GeminiModel()
alt = [GeminiModel.preprocessStatement_alt(q) for q in questions]

_embeddings = m.client.models.embed_content(
	model="gemini-embedding-001",
	contents=alt,
	config=types.EmbedContentConfig(task_type="FACT_VERIFICATION"),
)

# %%
q_embeddings = [e.values for e in _embeddings.embeddings]
q_embeddings
pol = loadPolicies()["openai"][
	"64b194a739dade62a6c90a81d803b42e298c2dcccb79a1f1fcca83df888ad67c"
]["policy_chunks"]

p_embeddings = np.stack([p["retreval_embedding_vector"] for p in pol])


# print(f"q_embeddings: {type(q_embeddings[0])}, {q_embeddings[0]}")
# print(f"q_embeddings: {type(p_embeddings[0])}, {p_embeddings[0]}")
def splitParargraphs(input_string):
	return input_string.split("\n\n")


def splitNewlines(input_string):
	while "\n\n" in input_string:
		input_string = input_string.replace("\n\n", "\n")
	return input_string.split("\n")


chunk_hashes = []
chunk_sections = []
for q in questions:
	entry = q_dict[q]
	hashes = []
	chunks = []
	for k, v in entry.items():
		if type(v) == list:
			for i in v:
				if type(i) == dict:
					if "chunk_hash" in i:
						hashes.append(i["chunk_hash"])
	chunk_hashes.append(hashes)


def getMostRelevant(question_embedding, chunk):
	pars = splitNewlines(chunk)

	_embeddings = m.client.models.embed_content(
		model="gemini-embedding-001",
		contents=pars,
		config=types.EmbedContentConfig(task_type="RETRIEVAL_DOCUMENT"),
	)
	embeddings = [e.values for e in _embeddings.embeddings]
	idx = np.argmax(np.dot(embeddings, question_embedding))
	return pars[idx]


for i, e in enumerate(q_embeddings):
	# print(e)
	idx = np.argmax(np.dot(p_embeddings, e))
	most_rel_hash = list(pol[idx].keys())[0]

	if most_rel_hash not in chunk_hashes[i]:
		print("miss")
		print(f"Question: {questions[i]}")

		print(f"Most relevant section: {most_rel_hash}")
		print(f"LLMs section: {chunk_hashes[i]}")
		print()
		# demo_hash = most_rel_hash	# chunk_hashes[i][0]
		demo_hash = chunk_hashes[i][0]
		sec = ""
		for i in pol:
			if demo_hash in i:
				sec = i[demo_hash]
		if sec != "":

			most_rel_part = getMostRelevant(e, sec)
			print(most_rel_part)
		print("---")
# sec = ""
# test_hash = "a58f6449acc07a431dd2bf48b20865edf2523f3c41b57eade43cc30d4ee25f07"
# for i in pol:
# 	if test_hash in i:
# 		sec = i[test_hash]

print(sec)

# p_embeddings
# Out:
# miss
# Question: Does the privacy policy affirm that the described practices relate to Personal Data collected when users use the company's services?
# Most relevant section: 71d65acf597a239d891187f32fd89fa994a3d2b43aa14e6343ec82f546ee2622
# LLMs section: ['a58f6449acc07a431dd2bf48b20865edf2523f3c41b57eade43cc30d4ee25f07']
#
# For individuals outside the European Economic Area, United Kingdom, and Switzerland, you can read this [version⁠](/policies/row-privacy-policy/) of our Privacy Policy
# ---
# miss
# Question: Does the privacy policy affirm that the references to "we," "our," or "us" include the company and its affiliates?
# Most relevant section: 7a32cf1311bbe67f865aa79a7b3c56f179f1d1f75ec50e77b78723d4a617a9ab
# LLMs section: ['a58f6449acc07a431dd2bf48b20865edf2523f3c41b57eade43cc30d4ee25f07']
#
# We at OpenAI OpCo, LLC (together with our affiliates, “OpenAI”, “we”, “our” or “us”) respect your privacy and are strongly committed to keeping secure any information we obtain from you or about you. This Privacy Policy describes our practices with respect to Personal Data that we collect from or about you when you use our website, applications, and services (collectively, “Services”).
# ---
# For individuals outside the European Economic Area, United Kingdom, and Switzerland, you can read this [version⁠](/policies/row-privacy-policy/) of our Privacy Policy
#
# We at OpenAI OpCo, LLC (together with our affiliates, “OpenAI”, “we”, “our” or “us”) respect your privacy and are strongly committed to keeping secure any information we obtain from you or about you. This Privacy Policy describes our practices with respect to Personal Data that we collect from or about you when you use our website, applications, and services (collectively, “Services”).
#
# This Privacy Policy does not apply to content that we process on behalf of customers of our business offerings, such as our API. Our use of that data is governed by our customer agreements covering access to and use of those offerings.
#
# For information about how we collect and use training information to develop our language models that power ChatGPT and other Services, and your choices with respect to that information, please see [this help center article⁠(opens in a new window)](https://help.openai.com/en/articles/7842364-how-chatgpt-and-our-language-models-are-developed).

# %% [markdown]
# <!-- `"We collect personal data relating to you (\u201cPersonal Data\u201d) as follows:\n\n**Personal Data You Provide:** We collect Personal Data if you create an account to use our Services or communicate with us as follows:\n\n* *Account Information:* When you create an account with us, we will collect information associated with your account, including your name, contact information, account credentials, date of birth, payment information, and transaction history, (collectively, \u201cAccount Information\u201d).\n* *User Content:* We collect Personal Data that you provide in the input to our Services (\u201cContent\u201d), including your prompts and other content you upload, such as [files\u2060(opens in a new window)](https://help.openai.com/en/articles/8555545-file-uploads-faq), [images\u2060(opens in a new window)](https://help.openai.com/en/articles/8400551-image-inputs-for-chatgpt-faq), and [audio\u2060(opens in a new window)](https://help.openai.com/en/articles/8400625-voice-chat-faq), depending on the features you use.\n* *Communication Information*: If you communicate with us, such as via email or our pages on social media sites, we may collect Personal Data like your name, contact information, and the contents of the messages you send (\u201cCommunication Information\u201d).\n* *Other Information You Provide*: We collect other information that you may provide to us, such as when you participate in our events or surveys or provide us with information to establish your identity or age (collectively, \u201cOther Information You Provide\u201d).\n\n**Personal Data We Receive from Your Use of the Services:** When you visit, use, or interact with the Services, we receive the following information about your visit, use, or interactions (\u201cTechnical Information\u201d):\n\n* *Log Data*: We collect information that your browser or device automatically sends when you use our Services. Log data includes your Internet Protocol address, browser type and settings, the date and time of your request, and how you interact with our Services.\n* *Usage Data*: We collect information about your use of the Services, such as the types of content that you view or engage with, the features you use and the actions you take, as well as your time zone, country, the dates and times of access, user agent and version, type of computer or mobile device, and your computer connection.\n* *Device Information*: We collect information about the device you use to access the Services, such as the name of the device, operating system, device identifiers, and browser you are using. Information collected may depend on the type of device you use and its settings.\n* *Location Information:* We may determine the general area from which your device accesses our Services based on information like its IP address for security reasons and to make your product experience better, for example to protect your account by detecting unusual login activity or to provide more accurate responses. In addition, some of our Services allow you to choose to provide more precise location information from your device, such as location information from your device\u2019s GPS.\n* *Cookies and Similar Technologies*: We use cookies and similar technologies to operate and administer our Services, and improve your experience. If you use our Services without creating an account, we may store some of the information described in this policy with cookies, for example to help maintain your preferences across browsing sessions. For details about our use of cookies, please read our [Cookie Notice](/policies/cookie-policy/).\n\n**Information We Receive from Other Sources:** We receive information from our trusted partners, such as security partners, to protect against fraud, abuse, and other security threats to our Services, and from marketing vendors who provide us with information about potential customers of our business services.\n\nWe also collect information from other sources, like information that is publicly available on the internet, to develop the models that power our Services. For more information on the sources of information used to develop the models that power ChatGPT and other Services, please see [this article](/policies/how-chatgpt-and-our-foundation-models-are-developed/).`
#
# `For individuals outside the European Economic Area, United Kingdom, and Switzerland, you can read this [version\u2060](/policies/row-privacy-policy/) of our Privacy Policy\n\nWe at OpenAI OpCo, LLC (together with our affiliates, \u201cOpenAI\u201d, \u201cwe\u201d, \u201cour\u201d or \u201cus\u201d) respect your privacy and are strongly committed to keeping secure any information we obtain from you or about you. This Privacy Policy describes our practices with respect to Personal Data that we collect from or about you when you use our website, applications, and services (collectively, \u201cServices\u201d).\n\nThis Privacy Policy does not apply to content that we process on behalf of customers of our business offerings, such as our API. Our use of that data is governed by our customer agreements covering access to and use of those offerings.\n\nFor information about how we collect and use training information to develop our language models that power ChatGPT and other Services, and your choices with respect to that information, please see [this help center article\u2060(opens in a new window)](https://help.openai.com/en/articles/7842364-how-chatgpt-and-our-language-models-are-developed).` -->

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 e
#
# NameError: name 'e' is not defined

# %%
stri = """We collect personal data relating to you (\u201cPersonal Data\u201d) as follows:\n\n**Personal Data You Provide:** We collect Personal Data if you create an account to use our Services or communicate with us as follows:\n\n* *Account Information:* When you create an account with us, we will collect information associated with your account, including your name, contact information, account credentials, date of birth, payment information, and transaction history, (collectively, \u201cAccount Information\u201d).\n* *User Content:* We collect Personal Data that you provide in the input to our Services (\u201cContent\u201d), including your prompts and other content you upload, such as [files\u2060(opens in a new window)](https://help.openai.com/en/articles/8555545-file-uploads-faq), [images\u2060(opens in a new window)](https://help.openai.com/en/articles/8400551-image-inputs-for-chatgpt-faq), and [audio\u2060(opens in a new window)](https://help.openai.com/en/articles/8400625-voice-chat-faq), depending on the features you use.\n* *Communication Information*: If you communicate with us, such as via email or our pages on social media sites, we may collect Personal Data like your name, contact information, and the contents of the messages you send (\u201cCommunication Information\u201d).\n* *Other Information You Provide*: We collect other information that you may provide to us, such as when you participate in our events or surveys or provide us with information to establish your identity or age (collectively, \u201cOther Information You Provide\u201d).\n\n**Personal Data We Receive from Your Use of the Services:** When you visit, use, or interact with the Services, we receive the following information about your visit, use, or interactions (\u201cTechnical Information\u201d):\n\n* *Log Data*: We collect information that your browser or device automatically sends when you use our Services. Log data includes your Internet Protocol address, browser type and settings, the date and time of your request, and how you interact with our Services.\n* *Usage Data*: We collect information about your use of the Services, such as the types of content that you view or engage with, the features you use and the actions you take, as well as your time zone, country, the dates and times of access, user agent and version, type of computer or mobile device, and your computer connection.\n* *Device Information*: We collect information about the device you use to access the Services, such as the name of the device, operating system, device identifiers, and browser you are using. Information collected may depend on the type of device you use and its settings.\n* *Location Information:* We may determine the general area from which your device accesses our Services based on information like its IP address for security reasons and to make your product experience better, for example to protect your account by detecting unusual login activity or to provide more accurate responses. In addition, some of our Services allow you to choose to provide more precise location information from your device, such as location information from your device\u2019s GPS.\n* *Cookies and Similar Technologies*: We use cookies and similar technologies to operate and administer our Services, and improve your experience. If you use our Services without creating an account, we may store some of the information described in this policy with cookies, for example to help maintain your preferences across browsing sessions. For details about our use of cookies, please read our [Cookie Notice](/policies/cookie-policy/).\n\n**Information We Receive from Other Sources:** We receive information from our trusted partners, such as security partners, to protect against fraud, abuse, and other security threats to our Services, and from marketing vendors who provide us with information about potential customers of our business services.\n\nWe also collect information from other sources, like information that is publicly available on the internet, to develop the models that power our Services. For more information on the sources of information used to develop the models that power ChatGPT and other Services, please see [this article](/policies/how-chatgpt-and-our-foundation-models-are-developed/)."""

print(splitParargraphs(stri))

# m = GeminiModel()


def splitParargraphs(input_string):
	return input_string.split("\n\n")


def joinParargraphs(string_array):
	return "\n\n".join(string_array)


def getEmbeddings(low_string, high_string):

	_embeddings = m.client.models.embed_content(
		model="gemini-embedding-001",
		contents=[low_string, high_string],
		config=types.EmbedContentConfig(task_type="RETRIEVAL_DOCUMENT"),
	)
	return [_embeddings.embeddings[0].values, _embeddings.embeddings[1].values]


def getMostRelevant(question_embedding, chunk):
	chunks = halfChunk(chunk)
	if len(chunks) == 1:
		return chunks[0]
	embedding_pair = getEmbeddings()
	idx = np.argmax(np.dot(embedding_pair, [question_embedding]))
	return getMostRelevant(chunks[idx])


def halfChunk(chunk):
	split = splitParargraphs(chunk)
	if len(split) == 1:
		return chunk
	half = len(split) // 2
	chunk_start = joinParargraphs(split[:half])
	chunk_end = joinParargraphs(split[half:])
	return [chunk_start, chunk_end]
# Out:
# ['We collect personal data relating to you (“Personal Data”) as follows:', '**Personal Data You Provide:** We collect Personal Data if you create an account to use our Services or communicate with us as follows:', '* *Account Information:* When you create an account with us, we will collect information associated with your account, including your name, contact information, account credentials, date of birth, payment information, and transaction history, (collectively, “Account Information”).\n* *User Content:* We collect Personal Data that you provide in the input to our Services (“Content”), including your prompts and other content you upload, such as [files\u2060(opens in a new window)](https://help.openai.com/en/articles/8555545-file-uploads-faq), [images\u2060(opens in a new window)](https://help.openai.com/en/articles/8400551-image-inputs-for-chatgpt-faq), and [audio\u2060(opens in a new window)](https://help.openai.com/en/articles/8400625-voice-chat-faq), depending on the features you use.\n* *Communication Information*: If you communicate with us, such as via email or our pages on social media sites, we may collect Personal Data like your name, contact information, and the contents of the messages you send (“Communication Information”).\n* *Other Information You Provide*: We collect other information that you may provide to us, such as when you participate in our events or surveys or provide us with information to establish your identity or age (collectively, “Other Information You Provide”).', '**Personal Data We Receive from Your Use of the Services:** When you visit, use, or interact with the Services, we receive the following information about your visit, use, or interactions (“Technical Information”):', '* *Log Data*: We collect information that your browser or device automatically sends when you use our Services. Log data includes your Internet Protocol address, browser type and settings, the date and time of your request, and how you interact with our Services.\n* *Usage Data*: We collect information about your use of the Services, such as the types of content that you view or engage with, the features you use and the actions you take, as well as your time zone, country, the dates and times of access, user agent and version, type of computer or mobile device, and your computer connection.\n* *Device Information*: We collect information about the device you use to access the Services, such as the name of the device, operating system, device identifiers, and browser you are using. Information collected may depend on the type of device you use and its settings.\n* *Location Information:* We may determine the general area from which your device accesses our Services based on information like its IP address for security reasons and to make your product experience better, for example to protect your account by detecting unusual login activity or to provide more accurate responses. In addition, some of our Services allow you to choose to provide more precise location information from your device, such as location information from your device’s GPS.\n* *Cookies and Similar Technologies*: We use cookies and similar technologies to operate and administer our Services, and improve your experience. If you use our Services without creating an account, we may store some of the information described in this policy with cookies, for example to help maintain your preferences across browsing sessions. For details about our use of cookies, please read our [Cookie Notice](/policies/cookie-policy/).', '**Information We Receive from Other Sources:** We receive information from our trusted partners, such as security partners, to protect against fraud, abuse, and other security threats to our Services, and from marketing vendors who provide us with information about potential customers of our business services.', 'We also collect information from other sources, like information that is publicly available on the internet, to develop the  ...
# 'We collect personal data relating to you (“Personal Data”) as follows:\n\n**Personal Data You Provide:** We collect Personal Data if you create an account to use our Services or communicate with us as follows:\n\n* *Account Information:* When you create an account with us, we will collect information associated with your account, including your name, contact information, account credentials, date of birth, payment information, and transaction history, (collectively, “Account Information”).\n* *User Content:* We collect Personal Data that you provide in the input to our Services (“Content”), including your prompts and other content you upload, such as [files\u2060(opens in a new window)](https://help.openai.com/en/articles/8555545-file-uploads-faq), [images\u2060(opens in a new window)](https://help.openai.com/en/articles/8400551-image-inputs-for-chatgpt-faq), and [audio\u2060(opens in a new window)](https://help.openai.com/en/articles/8400625-voice-chat-faq), depending on the features you use.\n* *Communication Information*: If you communicate with us, such as via email or our pages on social media sites, we may collect Personal Data like your name, contact information, and the contents of the messages you send (“Communication Information”).\n* *Other Information You Provide*: We collect other information that you may provide to us, such as when you participate in our events or surveys or provide us with information to establish your identity or age (collectively, “Other Information You Provide”).'

# %%
a = "asfjasfba"
a[:5]
# Out:
# 'asfja'

# %%
a[5:]
# Out:
# 'sfba'

# %%
from policy_analyser import loadQuestions

qs = loadQuestions()
for k in qs:
	print(k)
# Out:
# Does the privacy policy affirm that the policy explains how the company collects personal data?
# Does the privacy policy affirm that the policy explains how the company uses personal data?
# Does the privacy policy affirm that the policy explains how the company discloses personal data?
# Does the privacy policy affirm that the policy explains how the company processes personal data?
# Does the privacy policy affirm that the policy applies to instances where the company acts as a data controller?
# Does the privacy policy affirm that the policy applies when users interact with the company's products as a consumer for personal use?
# Does the privacy policy affirm that the policy applies when the company provides commercial customers and their end users access to its commercial products?
# Does the privacy policy affirm that the policy does not apply when the company acts as a data processor?
# Does the privacy policy affirm that the commercial customer is the controller when the company processes data on their behalf?
# Does the privacy policy affirm that the policy describes user privacy rights?
# Does the privacy policy affirm that the company collects the user's name when they sign up for an account?
# Does the privacy policy affirm that the company collects the user's email address when they sign up for an account?
# Does the privacy policy affirm that the company collects the user's phone number when they sign up for an account?
# Does the privacy policy affirm that the company collects identifiers when users sign up to receive information on the Services?
# Does the privacy policy affirm that the company may collect or generate indirect identifiers?
# Does the privacy policy affirm that the company shall collect payment information if a user chooses to purchase access to the company's products and services?
# Does the privacy policy affirm that third-party applications integrated by the user are included as Inputs to the Services?
# Does the privacy policy affirm that the company will collect personal data if a user includes it in their Inputs?
# Does the privacy policy affirm that the company will collect information if a user references external content in their Inputs?
# Does the privacy policy affirm that information included in Inputs may be reproduced in the resulting Outputs?
# Does the privacy policy affirm that if a user rates an Output, the company will store the entire related conversation as part of Feedback?
# Does the privacy policy affirm that the company collects the user's name if they communicate with the company?
# Does the privacy policy affirm that the company collects the user's contact information if they communicate with the company?
# Does the privacy policy affirm that the company collects the contents of any messages a user sends when communicating with the company?
# Does the privacy policy affirm that the company automatically receives certain technical data when the services are used?
# Does the privacy policy affirm that the collection of Device and Connection Information is consistent with user device or browser permissions?
# Does the privacy policy affirm that the company collects information about when users install, access, or use the Services?
# Does the privacy policy affirm that the company collects information about how users install, access, or use the Services?
# Does the privacy policy affirm that Device and Connection Information includes device type?
# Does the privacy policy affirm that Device and Connection Information includes operating system information?
# Does the privacy policy affirm that Device and Connection Information includes browser information?
# Does the privacy policy affirm that Device and Connection Information includes web page referers?
# Does the privacy policy affirm that Device and Connection Information includes mobile network details?
# Does the privacy policy affirm that Device and Connection Information includes connection information?
# Does the privacy policy affirm that Device and Connection Information includes mobile operator or internet service provider (ISP) details?
# Does the privacy policy affirm that Device and Connection Information includes time zone setting?
# Does the privacy policy affirm that Device and Connection Information includes IP address?
# Does the privacy policy affirm that information about the location of the device is derived from the IP address?
# Does the privacy policy affirm that Device and Connection Information includes device identifiers?
# Does the privacy policy affirm that Device and Connection Information includes advertising identifiers?
# Does the privacy policy affirm that Device and Connection Information includes probabilistic identifiers?
# Does the privacy policy affirm that Device and Connection Information includes unique personal or online identifiers?
# Does the privacy policy affirm that Device and Connection Information includes device location?
# Does the privacy policy affirm that the company collects Usage Information about the use of the Services?
# Does the privacy policy affirm that Usage Information includes the dates of access?
# Does the privacy policy affirm that Usage Information includes the times of access?
# Does the privacy policy affirm that Usage Information includes browsing history?
# Does the privacy policy affirm that Usage Information includes search information?
# Does the privacy policy affirm that Usage Information includes information about the links users click?
# Does the privacy policy affirm that Usage Information includes the pages users view?
# Does the privacy policy affirm that Usage Information includes information about the technology on the devices used to access the Services?
# Does the privacy policy affirm that the company collects information about the performance of the services when they are used?
# Does the privacy policy affirm that Log and Troubleshooting Information includes log files?
# Does the privacy policy affirm that the company may collect information about an error if one occurs?
# Does the privacy policy affirm that information collected about an error includes the time the error occurred?
# Does the privacy policy affirm that information collected about an error includes the feature being used?
# Does the privacy policy affirm that information collected about an error includes the state of the application when the error occurred?
# Does the privacy policy affirm that information collected about an error may include communications or content provided at the time the error occurred?
# Does the privacy policy affirm that the company uses cookies, scripts, or similar technologies to manage the Services?
# Does the privacy policy affirm that the company's service providers use cookies, scripts, or similar technologies to manage the Services?
# Does the privacy policy affirm that the company and its service providers use Cookies to collect information about the user?
# Does the privacy policy affirm that cookies help the company recognize the user?
# Does the privacy policy affirm that cookies help customize or personalize the user experience?
# Does the privacy policy affirm that cookies are used to market additional products or services to the user?
# Does the privacy policy affirm that cookies help analyze the use of the Services?
# Does the privacy policy affirm that the company analyzes the use of the Services via cookies to make them safer and more useful?
# Does the privacy policy affirm that the company obtains personal data from third party sources in order to train its models?
# Does the privacy policy affirm that the company trains its models using publicly available information via the Internet?
# Does the privacy policy affirm that the company trains its models using datasets obtained through commercial agreements with third party businesses?
# Does the privacy policy affirm that the company trains its models using data provided by users or crowd workers?
# Does the privacy policy affirm that the company trains its models using Inputs and Outputs from its Services?
# Does the privacy policy affirm that users can opt out of the company using Inputs and Outputs from the Services for model training?
# Does the privacy policy affirm that the company trains its models using feedback that users explicitly provide about the Services?
# Does the privacy policy affirm that the company trains its models using materials flagged for safety, security, or policy review?
# Does the privacy policy affirm that the company trains its models using data that it generates internally?
# Does the privacy policy affirm that information regarding how personal data is collected and used to develop the company's language models is available in a separate policy?
# Does the privacy policy affirm that information regarding the steps taken to minimize the privacy impact on individuals through the training process is available in a separate policy?
# Does the privacy policy affirm that information regarding user choices with respect to personal data used to develop language models is available in a separate policy?
# Does the privacy policy affirm that personal data is used to provide, maintain, and facilitate products and services offered with respect to the user's account?
# Does the privacy policy affirm that personal data is used to provide, maintain, and facilitate optional services and features that enhance platform functionality?
# Does the privacy policy affirm that personal data is used to provide, maintain, and facilitate optional services and features that enhance user experience?
# Does the privacy policy affirm that personal data is used to communicate with the user?
# Does the privacy policy affirm that personal data is used to send the user information about the services?
# Does the privacy policy affirm that personal data is used to send the user information about events?
# Does the privacy policy affirm that personal data is used to create the user's account?
# Does the privacy policy affirm that personal data is used to administer the user's account?
# Does the privacy policy affirm that personal data is used to facilitate payments for products and services provided by the company?
# Does the privacy policy affirm that personal data is used to prevent fraud?
# Does the privacy policy affirm that personal data is used to investigate fraud?
# Does the privacy policy affirm that personal data is used to prevent abuse?
# Does the privacy policy affirm that personal data is used to investigate abuse?
# Does the privacy policy affirm that personal data is used to investigate violations of the company's Usage Policy?
# Does the privacy policy affirm that personal data is used to prevent unlawful or criminal activity?
# Does the privacy policy affirm that personal data is used to investigate unlawful or criminal activity?
# Does the privacy policy affirm that personal data is used to prevent unauthorized access to or use of personal data?
# Does the privacy policy affirm that personal data is used to investigate unauthorized access to or use of personal data?
# Does the privacy policy affirm that personal data is used to prevent unauthorized access to or use of company systems and networks?
# Does the privacy policy affirm that personal data is used to investigate unauthorized access to or use of company systems and networks?
# Does the privacy policy affirm that personal data is used to protect the company's rights?
# Does the privacy policy affirm that personal data is used to protect the rights of others?
# Does the privacy policy affirm that personal data is used to meet legal, governmental, and institutional policy obligations?
# Does the privacy policy affirm that personal data is used to investigate and resolve disputes?
# Does the privacy policy affirm that personal data is used to investigate and resolve security issues?
# Does the privacy policy affirm that personal data is used to debug the services?
# Does the privacy policy affirm that personal data is used to identify errors that impair existing functionality?
# Does the privacy policy affirm that personal data is used to repair errors that impair existing functionality?
# Does the privacy policy affirm that personal data is used to improve the services?
# Does the privacy policy affirm that personal data is used to conduct research?
# Does the privacy policy affirm that personal data is used for training the company's models?
# Does the privacy policy affirm that personal data is used to enforce the company's Terms of Service?
# Does the privacy policy affirm that the company may use user Inputs and Outputs to train its models unless the user opts out through account settings?
# Does the privacy policy affirm that Inputs and Outputs will be used for model improvement, even if the user opts out, when conversations are flagged for safety review to improve the ability to detect harmful content?
# Does the privacy policy affirm that Inputs and Outputs will be used for model improvement, even if the user opts out, when conversations are flagged for safety review to enforce policies?
# Does the privacy policy affirm that Inputs and Outputs will be used for model improvement, even if the user opts out, when conversations are flagged for safety review to advance AI safety research?
# Does the privacy policy affirm that Inputs and Outputs will be used for model improvement, even if the user opts out, when the user has explicitly reported the materials to the company?
# Does the privacy policy affirm that the company may use user Inputs and Outputs to improve the services unless the user opts out through account settings?
# Does the privacy policy affirm that the company will disclose personal data to affiliates and corporate partners?
# Does the privacy policy affirm that the company discloses categories of personal data between and among its affiliates and related entities?
# Does the privacy policy affirm that the company may disclose categories of personal data with service providers and business partners?
# Does the privacy policy affirm that disclosure to service providers and business partners is for business purposes including website and data hosting?
# Does the privacy policy affirm that disclosure to service providers and business partners is for business purposes including ensuring compliance with industry standards?
# Does the privacy policy affirm that disclosure to service providers and business partners is for business purposes including research?
# Does the privacy policy affirm that disclosure to service providers and business partners is for business purposes including auditing?
# Does the privacy policy affirm that disclosure to service providers and business partners is for business purposes including data processing?
# Does the privacy policy affirm that disclosure to service providers and business partners is for business purposes including providing users with the services?
# Does the privacy policy affirm that the company will disclose personal data if it is involved in a merger, corporate transaction, or bankruptcy?
# Does the privacy policy affirm that the company will disclose personal data as part of corporate transactions involving the transfer of business assets?
# Does the privacy policy affirm that the company's services may involve integrations with websites, apps, and services managed by third parties?
# Does the privacy policy affirm that the company's services may direct users to websites, apps, and services managed by third parties?
# Does the privacy policy affirm that by interacting with integrated third parties, a user provides information directly to the third party?
# Does the privacy policy affirm that when interacting with integrated third parties, the user is subject to the third party’s privacy policy?
# Does the privacy policy affirm that third-party services accessed through the company's Services will be able to collect personal data about the user, including information about activity on the Services?
# Does the privacy policy affirm that users should read the data usage policies or documentation of sites or services linked via the company's Services?
# Does the privacy policy affirm that linking to another site or service does not mean the company endorses it?
# Does the privacy policy affirm that linking to another site or service does not mean the company speaks for that third party?
# Does the privacy policy affirm that the company may disclose personal data to governmental regulatory authorities as required by law?
# Does the privacy policy affirm that disclosure to governmental regulatory authorities includes purposes such as legal, tax, or accounting requirements?
# Does the privacy policy affirm that the company may disclose personal data in response to governmental regulatory requests for such information?
# Does the privacy policy affirm that the company may disclose personal data to assist in investigations by governmental regulatory authorities?
# Does the privacy policy affirm that the company may disclose personal data to third parties in connection with claims, disputes, or litigation?
# Does the privacy policy affirm that the company may disclose personal data when otherwise permitted or required by law?
# Does the privacy policy affirm that the company may disclose personal data if disclosure is necessary to protect the health and safety of the user or any other person?
# Does the privacy policy affirm that the company may disclose personal data to protect against fraud or credit risk?
# Does the privacy policy affirm that the company may disclose personal data to enforce its legal rights or the legal rights of others?
# Does the privacy policy affirm that the company may disclose personal data to enforce contractual commitments made by the user?
# Does the privacy policy affirm that the company will otherwise disclose personal data when an individual gives permission for disclosure?
# Does the privacy policy affirm that the company will otherwise disclose personal data when an individual directs the company to disclose this information?
# Does the privacy policy affirm that the company engages third parties to help process personal data when the company acts as a data processor?
# Does the privacy policy affirm that the company acts as a data processor concerning personal data received, processed, stored, or hosted when users utilize its commercial services?
# Does the privacy policy affirm that information about the third parties the company engages as Subprocessors is available on a Subprocessor List?
# Does the privacy policy affirm that users may enjoy certain rights regarding their personal data depending on where they live and the applicable laws?
# Does the privacy policy affirm that user rights regarding personal data are limited?
# Does the privacy policy affirm that the process for actioning user requests regarding the company's training dataset is complex?
# Does the privacy policy affirm that the company may decline a request if there is a lawful reason for doing so?
# Does the privacy policy affirm that the company complies with all applicable privacy laws?
# Does the privacy policy affirm that users or an authorized agent may submit a request to exercise their rights by emailing the company?
# Does the privacy policy affirm that the company may verify a request by asking for information sufficient to confirm the user's identity?
# Does the privacy policy affirm that users may have the right to appeal denied requests by contacting the company via email?
# Does the privacy policy affirm that the company will not discriminate based on the exercising of user privacy rights?
# Does the privacy policy affirm that users have the right to know what personal data the company processes about them?
# Does the privacy policy affirm that users have the right to know the categories of personal data processed?
# Does the privacy policy affirm that users have the right to know the categories of sources from which personal data is collected?
# Does the privacy policy affirm that users have the right to know the business or commercial purposes for data collection?
# Does the privacy policy affirm that users have the right to know the categories of third parties to whom data is disclosed?
# Does the privacy policy affirm that users have the right to request a copy of the personal data the company processes about them, subject to certain exceptions and conditions?
# Does the privacy policy affirm that users have the right to port their information in certain cases and subject to applicable law?
# Does the privacy policy affirm that users have the right to request the deletion of personal data collected from them when using the services, subject to certain exceptions?
# Does the privacy policy affirm that users are able to delete individual conversations?
# Does the privacy policy affirm that deleted individual conversations will be removed immediately from the conversation history?
# Does the privacy policy affirm that deleted individual conversations will be automatically deleted from the back-end within 30 days?
# Does the privacy policy affirm that users have the right to request the correction of inaccurate personal data retained by the company, subject to certain exceptions?
# Does the privacy policy affirm that the company cannot guarantee the factual accuracy of Outputs generated by its models?
# Does the privacy policy affirm that users can submit a correction request if Outputs contain factually inaccurate personal data relating to them?
# Does the privacy policy affirm that the company will make a reasonable effort to correct factually inaccurate personal data in Outputs?
# Does the privacy policy affirm that correcting factually inaccurate personal data in Outputs may not always be possible due to the technical complexity of the large language models?
# Does the privacy policy affirm that users have the right to object to the processing of their personal data?
# Does the privacy policy affirm that users have the right to object to profiling conducted on grounds of public or legitimate interest?
# Does the privacy policy affirm that following an objection, the company will cease processing personal data unless it demonstrates compelling legitimate grounds for processing?
# Does the privacy policy affirm that users can object and opt out of future direct marketing messages using the unsubscribe link in communications?
# Does the privacy policy affirm that users have the right to restrict the processing of their personal data in certain circumstances?
# Does the privacy policy affirm that users have the right to withdraw their consent where processing is based on consent?
# Does the privacy policy affirm that the withdrawal of consent will not affect the lawfulness of processing based on consent before its withdrawal?
# Does the privacy policy affirm that the company does not engage in decision-making based solely on automated processing that produces a legal effect or significantly affects the user?
# Does the privacy policy affirm that the company does not sell personal data as defined by applicable laws and regulations?
# Does the privacy policy affirm that users can opt-out of sharing their personal data for targeted advertising used to promote the company's products and services?
# Does the privacy policy affirm that the company will honor global privacy controls regarding targeted marketing?
# Does the privacy policy affirm that the company gives users access to a variety of tools to help them manage their data?
# Does the privacy policy affirm that personal data may be transferred to the company's servers in the US when accessing the website or services?
# Does the privacy policy affirm that personal data may be transferred to countries outside the European Economic Area (EEA) and the UK when accessing the website or services?
# Does the privacy policy affirm that the transfer of personal data outside the EEA or the UK may be a direct provision of data by the user to the company?
# Does the privacy policy affirm that the company may make transfers of personal data outside the EEA or the UK?
# Does the privacy policy affirm that a third party may make transfers of personal data outside the EEA or the UK?
# Does the privacy policy affirm that the company ensures information transferred outside the EEA or the UK benefits from an adequate level of data protection?
# Does the privacy policy affirm that the company relies on adequacy decisions when transferring information outside the EEA or the UK?
# Does the privacy policy affirm that adequacy decisions are decisions from the European Commission under Article 45 GDPR?
# Does the privacy policy affirm that the company transfers user information to some countries based on adequacy decisions?
# Does the privacy policy affirm that the company relies on Standard Contractual Clauses when transferring information outside the EEA or the UK?
# Does the privacy policy affirm that Standard Contractual Clauses were approved by the European Commission under Article 46 GDPR?
# Does the privacy policy affirm that Standard Contractual Clauses allow companies in the EEA to transfer data outside the EEA?
# Does the privacy policy affirm that the company relies on Standard Contractual Clauses to transfer information to certain affiliates in countries without an adequacy decision?
# Does the privacy policy affirm that the company relies on Standard Contractual Clauses to transfer information to certain third parties in countries without an adequacy decision?
# Does the privacy policy affirm that Standard Contractual Clauses include approved equivalents for the UK and Switzerland?
# Does the privacy policy affirm that the company relies on derogations under applicable data protection law to transfer information to a third country in certain situations?
# Does the privacy policy affirm that the company retains personal data for as long as reasonably necessary for the purposes and criteria outlined in the Privacy Policy?
# Does the privacy policy affirm that the company will perform necessary procedures for destroying personal data when it is no longer required?
# Does the privacy policy affirm that the company will perform necessary procedures for deleting personal data when it is no longer required?
# Does the privacy policy affirm that the company will perform necessary procedures for erasing personal data when it is no longer required?
# Does the privacy policy affirm that the company will perform necessary procedures for converting personal data into an anonymous form when it is no longer required?
# Does the privacy policy affirm that service providers will perform necessary procedures for destroying, deleting, erasing, or anonymizing personal data when it is no longer required by the company?
# Does the privacy policy affirm that the procedures for data disposition are performed as permitted or required under applicable laws?
# Does the privacy policy affirm that personal data may be processed in an aggregated or de-identified form?
# Does the privacy policy affirm that aggregated or de-identified data is processed to analyze the effectiveness of the service?
# Does the privacy policy affirm that aggregated or de-identified data is processed to conduct research?
# Does the privacy policy affirm that aggregated or de-identified data is processed to study user behavior?
# Does the privacy policy affirm that aggregated or de-identified data is processed to train the company's AI models?
# Does the privacy policy affirm that when Feedback is submitted, the company disassociates the Inputs and Outputs from the user ID?
# Does the privacy policy affirm that disassociated Inputs and Outputs from Feedback are used for training and improving the company's models?
# Does the privacy policy affirm that if systems flag Inputs or Outputs for potential Usage Policy violations, the company disassociates the content from the user ID?
# Does the privacy policy affirm that flagged and disassociated content is used to train the company's trust and safety internal classification and generative models?
# Does the privacy policy affirm that flagged Inputs or Outputs may be re-identified if necessary to enforce the Usage Policy?
# Does the privacy policy affirm that the company may analyze and aggregate general user behavior and usage data to improve user experience?
# Does the privacy policy affirm that the analyzed and aggregated general user behavior and usage data does not identify individual users?
# Does the privacy policy affirm that the company implements appropriate technical and organizational security measures?
# Does the privacy policy affirm that security measures are designed to protect personal data from loss?
# Does the privacy policy affirm that security measures are designed to protect personal data from misuse?
# Does the privacy policy affirm that security measures are designed to protect personal data from unauthorized access?
# Does the privacy policy affirm that security measures are designed to protect personal data from disclosure?
# Does the privacy policy affirm that security measures are designed to protect personal data from alteration?
# Does the privacy policy affirm that security measures are designed to protect personal data from destruction?
# Does the privacy policy affirm that the services are not directed towards children under the age of 18?
# Does the privacy policy affirm that the company does not knowingly collect any information from children under the age of 18?
# Does the privacy policy affirm that the company does not knowingly use any information from children under the age of 18?
# Does the privacy policy affirm that the company does not knowingly disclose any information from children under the age of 18?
# Does the privacy policy affirm that the company does not knowingly sell any information from children under the age of 18?
# Does the privacy policy affirm that the company does not knowingly share any information from children under the age of 18?
# Does the privacy policy affirm that users should contact the company via email if they become aware a child under the age of 18 has provided personal data?
# Does the privacy policy affirm that the company will investigate if notified that a child under 18 has provided personal data?
# Does the privacy policy affirm that the company will delete the personal data provided by a child under 18 if deemed appropriate after investigation?
# Does the privacy policy affirm that the company may update this Privacy Policy from time to time?
# Does the privacy policy affirm that the company will notify users of any material changes to this Privacy Policy?
# Does the privacy policy affirm that the company will update the Effective Date at the top of the privacy policy webpage?
# Does the privacy policy affirm that users can view a summary of privacy policy changes?
# Does the privacy policy affirm that previous versions of the privacy policy are available to view?
# Does the privacy policy affirm that a specific company entity is the data controller responsible for personal data of users living in the European Economic Area, UK, or Switzerland?
# Does the privacy policy affirm that a specific company entity is the data controller responsible for personal data of users living outside the European Economic Area, UK, or Switzerland?
# Does the privacy policy affirm that users can contact the company with questions, complaints, or requests regarding their personal data or the Privacy Policy?
# Does the privacy policy affirm that users can contact the company via email for general privacy-related inquiries?
# Does the privacy policy affirm that users can contact the Data Protection Officer via email?
# Does the privacy policy affirm that users in many countries have the right to lodge a complaint with the supervisory authority where they live or work?
# Does the privacy policy affirm that users living or working in the UK have the right to lodge a complaint with the UK Information Commissioner’s Office?
# Does the privacy policy affirm that users living in Brazil have the right to lodge a complaint with the Brazilian Data Protection Authority (ANPD)?
# Does the privacy policy affirm that users living in Australia have the right to lodge a complaint with the Office of the Australian Information Commissioner?
# Does the privacy policy affirm that Identity and Contact Data is processed to provide, maintain, and facilitate the products and services related to a user's account?
# Does the privacy policy affirm that Payment Information is processed to provide, maintain, and facilitate the products and services related to a user's account?
# Does the privacy policy affirm that Feedback is processed to provide, maintain, and facilitate the products and services related to a user's account?
# Does the privacy policy affirm that Inputs and Outputs are processed to provide, maintain, and facilitate the products and services related to a user's account?
# Does the privacy policy affirm that Technical Information is processed to provide, maintain, and facilitate the products and services related to a user's account?
# Does the privacy policy affirm that the legal basis for processing data to provide, maintain, and facilitate products and services related to a user's account is Contract?
# Does the privacy policy affirm that Identity and Contact Data is processed to facilitate optional services and features that enhance platform functionality?
# Does the privacy policy affirm that Feedback is processed to facilitate optional services and features that enhance platform functionality?
# Does the privacy policy affirm that Inputs and Outputs are processed to facilitate optional services and features that enhance platform functionality?
# Does the privacy policy affirm that Technical Information is processed to facilitate optional services and features that enhance platform functionality?
# Does the privacy policy affirm that Consent is the legal basis for processing precise device location data to provide optional services and features?
# Does the privacy policy affirm that Legitimate interests is a legal basis for processing data to expand product features and deliver additional services that enhance platform functionality?
# Does the privacy policy affirm that Identity and Contact Data is processed to communicate with the user and to promote the services?
# Does the privacy policy affirm that Communication Information is processed to communicate with the user and to promote the services?
# Does the privacy policy affirm that Technical Information is processed to communicate with the user and to promote the services?
# Does the privacy policy affirm that performing a contract is a legal basis for processing contact information to send a technical announcement about the services?
# Does the privacy policy affirm that user consent is the legal basis when processing contact information to send certain forms of marketing communications?
# Does the privacy policy affirm that Legitimate Interests is a legal basis for promoting the services and sending direct marketing?
# Does the privacy policy affirm that Identity and Contact Data is processed to create and administer the user's account?
# Does the privacy policy affirm that Payment Information is processed to create and administer the user's account?
# Does the privacy policy affirm that Feedback is processed to create and administer the user's account?
# Does the privacy policy affirm that the legal basis for processing data to create and administer the user's account is Contract?
# Does the privacy policy affirm that Identity and Contact Data is processed to facilitate payments for products and services provided by the company?
# Does the privacy policy affirm that Payment Information is processed to facilitate payments for products and services provided by the company?
# Does the privacy policy affirm that the legal basis for processing data to facilitate payments is Contract?
# Does the privacy policy affirm that Identity and Contact Data is processed to prevent and investigate fraud, abuse, and unlawful activity?
# Does the privacy policy affirm that Payment Information is processed to prevent and investigate fraud, abuse, and unlawful activity?
# Does the privacy policy affirm that Inputs and Outputs are processed to prevent and investigate fraud, abuse, and unlawful activity?
# Does the privacy policy affirm that Technical Information is processed to prevent and investigate fraud, abuse, and unlawful activity?
# Does the privacy policy affirm that data is processed to protect the company's rights and the rights of others?
# Does the privacy policy affirm that data is processed to meet legal, governmental, and institutional policy obligations?
# Does the privacy policy affirm that Legitimate interests is a legal basis for processing data to protect the company, employees, and users from illegal activities?
# Does the privacy policy affirm that Legal obligation is a legal basis for processing data to cooperate with authorities?
# Does the privacy policy affirm that Identity and Contact Data is processed to investigate and resolve disputes?
# Does the privacy policy affirm that Inputs and Outputs are processed to investigate and resolve disputes?
# Does the privacy policy affirm that Feedback is processed to investigate and resolve disputes?
# Does the privacy policy affirm that Legitimate interests is a legal basis for resolving customer complaints to improve user satisfaction?
# Does the privacy policy affirm that Legal obligation is a legal basis in some cases for investigating and resolving disputes?
# Does the privacy policy affirm that Identity and Contact Data is processed to investigate and resolve security issues?
# Does the privacy policy affirm that Feedback is processed to investigate and resolve security issues?
# Does the privacy policy affirm that Technical Information is processed to investigate and resolve security issues?
# Does the privacy policy affirm that Inputs and Outputs are processed to investigate and resolve security issues?
# Does the privacy policy affirm that Legitimate interests is a legal basis for protecting user data and systems from intrusion through monitoring and swift response?
# Does the privacy policy affirm that Legal obligation is a legal basis for providing adequate security safeguards?
# Does the privacy policy affirm that Identity and Contact Data is processed to debug and repair errors that impair existing functionality?
# Does the privacy policy affirm that Feedback is processed to debug and repair errors that impair existing functionality?
# Does the privacy policy affirm that Technical Information is processed to debug and repair errors that impair existing functionality?
# Does the privacy policy affirm that Legitimate interests is the legal basis for maintaining continuous functioning of the services and rapid correction of problems?
# Does the privacy policy affirm that Identity and Contact Data is processed to improve the services and conduct research, excluding model training?
# Does the privacy policy affirm that Feedback is processed to improve the services and conduct research, excluding model training?
# Does the privacy policy affirm that Technical Information is processed to improve the services and conduct research, excluding model training?
# Does the privacy policy affirm that Inputs and Outputs are processed to improve the services and conduct research, excluding model training?
# Does the privacy policy affirm that Legitimate interests is the legal basis for evaluating the use of the services to inform the development of future features?
# Does the privacy policy affirm that research conducted by the company benefits the AI industry and society?
# Does the privacy policy affirm that Feedback is processed to improve the services and conduct research, including model training?
# Does the privacy policy affirm that Inputs and Outputs are processed to improve the services and conduct research, including model training?
# Does the privacy policy affirm that data provided through the Development Partner Program is processed to improve the services and conduct research, including model training?
# Does the privacy policy affirm that Consent is the legal basis for processing Feedback used for improving the services and conducting research, including model training?
# Does the privacy policy affirm that Legitimate interests is the legal basis for improving direction and development of the services?
# Does the privacy policy affirm that Identity and Contact Data is processed to enforce the company's Terms of Service and similar agreements?
# Does the privacy policy affirm that Inputs and Outputs are processed to enforce the company's Terms of Service and similar agreements?
# Does the privacy policy affirm that Technical Information is processed to enforce the company's Terms of Service and similar agreements?
# Does the privacy policy affirm that Contract is a legal basis for processing data used to enforce the company's terms and agreements?
# Does the privacy policy affirm that Legitimate interests is a legal basis for enforcing the rules and policies governing the use of the company's services outside of contract performance?
# Does the privacy policy affirm that the supplemental disclosures contain additional information relevant to residents of Canada?
# Does the privacy policy affirm that the supplemental disclosures shall prevail over the main Privacy Policy in relation to residents of Canada if a conflict arises?
# Does the privacy policy affirm that expressly consenting to the Privacy Policy confirms the user's consent to the collection of their personal data?
# Does the privacy policy affirm that expressly consenting to the Privacy Policy confirms the user's consent to the use of their personal data?
# Does the privacy policy affirm that expressly consenting to the Privacy Policy confirms the user's consent to the processing of their personal data?
# Does the privacy policy affirm that expressly consenting to the Privacy Policy confirms the user's consent to the disclosure of their personal data?
# Does the privacy policy affirm that the company relies on other lawful bases for data handling in jurisdictions where such bases are available?
# Does the privacy policy affirm that personal data is only collected with consent, unless otherwise permitted or required by law?
# Does the privacy policy affirm that personal data is only used with consent, unless otherwise permitted or required by law?
# Does the privacy policy affirm that personal data is only disclosed with consent, unless otherwise permitted or required by law?
# Does the privacy policy affirm that user consent may be given expressly?
# Does the privacy policy affirm that user consent may be implied depending on the circumstances?
# Does the privacy policy affirm that users may withdraw consent at any time, subject to legal or contractual restrictions?
# Does the privacy policy affirm that providing personal data acknowledges agreement that the data may be transferred outside of Canada?
# Does the privacy policy affirm that providing personal data acknowledges agreement that the data may be disclosed to jurisdictions outside of Canada?
# Does the privacy policy affirm that personal data transferred or disclosed to other jurisdictions outside of Canada is for processing and storage?
# Does the privacy policy affirm that personal data may be transferred to the United States?
# Does the privacy policy affirm that personal data may be transferred to the countries listed on the company's subprocessor list?
# Does the privacy policy affirm that laws regarding personal data protection in jurisdictions outside of Canada, such as the United States, may be less stringent than the laws in the user's jurisdiction?
# Does the privacy policy affirm that the company may disclose personal data in jurisdictions outside of Canada in response to legal processes?
# Does the privacy policy affirm that the company may disclose personal data outside of Canada where it believes in good faith that disclosure is required or permitted by law?
# Does the privacy policy affirm that users can contact the company via email regarding questions about the processing of their personal data?
# Does the privacy policy affirm that users can contact the company via email to exercise their rights outlined in Section 4 (“Rights and Choices”)?
# Does the privacy policy affirm that supplemental disclosures prevail over the main Privacy Policy in case of conflict in relation to residents of Brazil?
# Does the privacy policy affirm that the company may rely on different legal grounds than those listed in section 2 of the main policy, where permitted by and in accordance with the Brazilian General Data Protection Law (LGPD)?
# Does the privacy policy affirm that the company may rely on the "exercise of legal rights" basis to process personal data associated with customer complaints?
# Does the privacy policy affirm that the company may rely on the "exercise of legal rights" basis to enforce its Terms of Service and similar terms and agreements?
# Does the privacy policy affirm that the LGPD grants certain rights regarding personal data that differ from those listed under section 4 of the main policy?
# Does the privacy policy affirm that the company will respond to requests to exercise LGPD rights in accordance with applicable law?
# Does the privacy policy affirm that Brazilian residents have the right to receive a confirmation on whether the company processes their data?
# Does the privacy policy affirm that Brazilian residents have the right to know what personal data the company processes about them?
# Does the privacy policy affirm that Brazilian residents have the right to request the correction of data that is incomplete, inaccurate, or outdated?
# Does the privacy policy affirm that Brazilian residents have the right to request the anonymization of data that is unnecessary?
# Does the privacy policy affirm that Brazilian residents have the right to request the blocking of excessive data?
# Does the privacy policy affirm that Brazilian residents have the right to request the erasure of data processed in non-compliance with the provisions of the law?
# Does the privacy policy affirm that Brazilian residents have the right to request portability of their data to a third-party, provided this does not infringe on the company's trade secrets?
# Does the privacy policy affirm that Brazilian residents have the right to request information of public and private entities with which the company has shared data?
# Does the privacy policy affirm that Brazilian residents have the right to request information about the possibility to refuse to provide consent and the respective consequences, when applicable?
# Does the privacy policy affirm that Brazilian residents have the right to withdraw their consent?
# Does the privacy policy affirm that the procedure for withdrawal of consent will be carried out free of charge?
# Does the privacy policy affirm that Brazilian residents have the right to request a review of decisions made solely based on automated processing of personal data?
# Does the privacy policy affirm that the LGPD rights are not absolute and may not apply in certain circumstances?
# Does the privacy policy affirm that the company may continue to process and retain data regardless of a request for deletion to comply with legal, contractual, and regulatory obligations?
# Does the privacy policy affirm that the company may continue to process and retain data regardless of a request for objection in order to safeguard and exercise rights, including in judicial proceedings?
# Does the privacy policy affirm that the company is based and headquartered in the United States?
# Does the privacy policy affirm that information held about the user will be transferred to, used, processed, and stored in the United States?
# Does the privacy policy affirm that international transfers of personal data are necessary for the proper operation of the Services?
# Does the privacy policy affirm that for data transfers in the case of Brazil, the company will rely on standard contractual clauses (SCCs) where required?
# Does the privacy policy affirm that standard contractual clauses (SCCs) are used for data transfers in instances where they are not covered by an adequacy decision?
# Does the privacy policy affirm that the SCCs adopted have been approved by the Brazilian Data Protection Authority (ANPD)?
# Does the privacy policy affirm that the Brazilian Data Protection Authority (ANPD) is the competent supervisory authority for data transfers as governed by Brazilian Data Protection Laws?
# Does the privacy policy affirm that the company has a domestic representative in the Republic of Korea for data protection and related regulatory purposes?
# Does the privacy policy affirm that the registered physical address of the domestic representative is in Seoul, South Korea?
# Does the privacy policy affirm that users can contact the domestic representative via telephone?
# Does the privacy policy affirm that users can contact the domestic representative via email?
# Does the privacy policy affirm that a specific legal entity is entrusted as a data processor (Trustee)?
# Does the privacy policy affirm that the entrusted data includes the Name of the user?
# Does the privacy policy affirm that the entrusted data includes the ID of the user?
# Does the privacy policy affirm that the entrusted data includes the phone number of the user?
# Does the privacy policy affirm that the entrusted data includes the email address of the user?
# Does the privacy policy affirm that the entrusted data includes the physical address of the user?
# Does the privacy policy affirm that the entrusted data includes other information provided by the user to the domestic representative?
# Does the privacy policy affirm that the purpose of data processing by the Trustee is assisting with the domestic representative duties?
# Does the privacy policy affirm that the data recipient's location for the entrusted processing is South Korea?
# Does the privacy policy affirm that the retention period for entrusted data is the period necessary to process the user's request?
# Does the privacy policy affirm that data transfer methods utilized by the domestic representative include telephone?
# Does the privacy policy affirm that data transfer methods utilized by the domestic representative include text messaging?
# Does the privacy policy affirm that data transfer methods utilized by the domestic representative include email?

# %%
# AnalysisProcessor.extractContent(
# 	"https://cdn.deepseek.com/policies/en-US/deepseek-privacy-policy.html"
# )

# %% [markdown]
# - Remove questions that contain flag words like OpenAI and Anthropic

# %% [markdown]
# Questions should contain one unique affirmation and should be as consice as possible. For example instead of `Does the privacy policy affirm that account creation leads to the collection of the user's name, contact information, account credentials, date of birth, payment information, and transaction history?`, you should generate 6 questions:
# ```
# Does the privacy policy affirm that account creation leads to the collection of the user's name?
# Does the privacy policy affirm that account creation leads to the collection of contact information?
# Does the privacy policy affirm that account creation leads to the collection of account credentials?
# Does the privacy policy affirm that account creation leads to the collection of payment information?
# Does the privacy policy affirm that account creation leads to the collection of transaction history?
# ```
#
# Each affirmation must not be self referential to the document structure, for example: `Does the privacy policy affirm that Section 11 contains provisions that apply specifically to users located in Canada?` is an invalid question, since it is to do with the document itself. We should omit questions like that unless the relevent text is in the document, then we should similarly proceed with direct affirmation questions, to do with the specific information.

# %% [markdown]
# **Atomicity Constraint:** Each generated question must contain only one unique, verifiable affirmation (one single fact, policy, or commitment). Questions must be concise. Do not combine multiple facts, data points, or policy clauses into a single question.
#
# For example, instead of the multi-fact question:
# `Does the policy affirm that account creation leads to the collection of the user's name, contact information, account credentials, date of birth, payment information, and transaction history?`
#
# You must generate six separate, atomic questions, such as:
# ```
# Does the privacy policy affirm that account creation leads to the collection of the user's name?
# Does the privacy policy affirm that account creation leads to the collection of contact information?
# Does the privacy policy affirm that account creation leads to the collection of account credentials?
# Does the privacy policy affirm that account creation leads to the collection of payment information?
# Does the privacy policy affirm that account creation leads to the collection of transaction history?
# ```
#
#
# Affirmation questions must pertain directly to the policies, actions, disclosures, or specific commitments described within this text snippet. Questions must not be self-referential to the document's structure, chapter titles, internal cross-references, or numbering scheme, **unless that structural element is the primary subject of the question and explicitly stated in the provided text.**
#
# For example, questions about implied structure or location (e.g., `Does the privacy policy affirm that Section 11 contains provisions that apply specifically to users located in Canada?`) are invalid, as Section 11 is not present.
#
# Instead, focus only on the specific policy dictates, such as: `Does the policy affirm that data for Canadian residents may be transferred to jurisdictions where data protection laws are less stringent?`

# %% [markdown]
# Does the privacy policy affirm that account creation leads to the collection of the user's name, contact information, account credentials, date of birth, payment information, and transaction history?
#
# Does the privacy policy affirm that OpenAI OpCo, LLC is the controller responsible for processing Personal Data of users living in the UK?
#
# Does the privacy policy affirm that Section 11 contains provisions that apply specifically to users located in Canada?
#
# Does the privacy policy affirm that Anthropic Ireland, Limited is the data controller responsible for personal data of users who live in the European Region (EEA, UK, or Switzerland)?

# %%
from policy_analyser import loadQuestions

qs = loadQuestions()
for k in qs:
	print(k)

# %%
import numpy as np
from model_management import GeminiModel

# question_1 = "Does the privacy policy affirm that personal data transfers are automatically consented to by using the service?"
# question_1_prime = "Does the privacy policy affirm that user data transfers are automatically consented to by using the service?"
# question_2 = "Does the privacy policy affirm that personal data processing is automatically consented to by using the service?"

question_1 = "Does the privacy policy affirm that personal data processing is automatically consented to by using the service?"
question_1_prime = "Does the privacy policy affirm that processing of personal data is automatically consented to by using the service?"
question_2 = "Does the privacy policy affirm that personal data transfers are automatically consented to by using the service?"

preprocess_question_1 = GeminiModel.preprocessStatement(question_1)
preprocess_question_1_prime = GeminiModel.preprocessStatement(question_1_prime)
preprocess_question_2 = GeminiModel.preprocessStatement(question_2)


preprocess_question_1_alt = GeminiModel.preprocessStatement_alt(question_1)
preprocess_question_1_prime_alt = GeminiModel.preprocessStatement_alt(question_1_prime)
preprocess_question_2_alt = GeminiModel.preprocessStatement_alt(question_2)

original = [question_1, question_1_prime, question_2]

preprocess_main = [
	preprocess_question_1,
	preprocess_question_1_prime,
	preprocess_question_2,
]
preprocess_alt = [
	preprocess_question_1_alt,
	preprocess_question_1_prime_alt,
	preprocess_question_2_alt,
]


task_types = [
	"SEMANTIC_SIMILARITY",
	"QUESTION_ANSWERING",
	"CLASSIFICATION",
	"CLUSTERING",
	"RETRIEVAL_DOCUMENT",
	"RETRIEVAL_QUERY",
	"FACT_VERIFICATION",
]
# add Mahalanobis later for entire dataset


def pQs():
	model = GeminiModel()

	def processEmbeddings(q_set):
		embs = {}
		for i in task_types:
			emb_1 = model.getSemanticEmbedding(q_set[0], task_type=i)
			emb_1_prime = model.getSemanticEmbedding(q_set[1], task_type=i)
			emb_2 = model.getSemanticEmbedding(q_set[2], task_type=i)
			embs.update({i: [emb_1, emb_1_prime, emb_2]})
		return embs

	return {
		"Original": processEmbeddings(original),
		"Main": processEmbeddings(preprocess_main),
		"Alt": processEmbeddings(preprocess_alt),
	}


embedding_sets = pQs()

# %%
import re


cleaned_result = cleanString(input_text)

print(f"Original String: '{input_text}'")
print(f"Cleaned String:  '{cleaned_result}'")

# %%
def processQsets(embedding_sets, similarity="cosine"):

	similarity_processors = {
		"cosine": lambda emb_a, emb_b: np.dot(emb_a, emb_b)
		/ (np.linalg.norm(emb_a) * np.linalg.norm(emb_b)),
		"l1": lambda emb_a, emb_b: np.linalg.norm(np.array(emb_a) - np.array(emb_b), ord=1),
		"l2": lambda emb_a, emb_b: np.linalg.norm(np.array(emb_a) - np.array(emb_b), ord=2),
		"dot": lambda emb_a, emb_b: np.dot(emb_a, emb_b),
	}
	if similarity not in similarity:
		similarity = "cosine"

	similarityProcessor = similarity_processors[similarity]

	data = {}

	for k, v in embedding_sets.items():
		_data = {}
		for l, w in v.items():
			[emb_1, emb_1_prime, emb_2] = w
			semantically_identical = similarityProcessor(emb_1, emb_1_prime)
			lexically_similar = similarityProcessor(emb_1, emb_2)
			delta = semantically_identical - lexically_similar
			_data.update(
				{
					l: {
						"semantically_identical": semantically_identical,
						"lexically_similar": lexically_similar,
						"delta": delta,
					}
				}
			)
		data.update({k: _data})
	return data

# %%
import pandas as pd

data = processQsets(embedding_sets, "dot")


reformatted_data = {
	(outer_key, inner_key): values
	for outer_key, inner_dict in data.items()
	for inner_key, values in inner_dict.items()
}

df = pd.DataFrame.from_dict(reformatted_data, orient="index")

df.index.names = ["Setting", "Task Type"]
pd.set_option("display.width", 1000)
print(df)

df_sorted = df.sort_values(by="delta", ascending=False)
print("--- ordered ---")
print(df_sorted)

# %%
# data = processQsets("dot")

# %%
a = "f"

b = {"f": 1}

a in b

# %% [markdown]
# # Cosine
#                               semantically_identical  lexically_similar     delta
# Setting  Task Type
# Original SEMANTIC_SIMILARITY                0.997794           0.970933  0.026861
#          QUESTION_ANSWERING                 0.984825           0.898482  0.086343
#          CLASSIFICATION                     0.987050           0.929606  0.057444
#          CLUSTERING                         0.995677           0.966805  0.028872
#          RETRIEVAL_DOCUMENT                 0.995890           0.957301  0.038589
#          RETRIEVAL_QUERY                    0.985738           0.910084  0.075654
#          FACT_VERIFICATION                  0.986830           0.909675  0.077155
# Main     SEMANTIC_SIMILARITY                0.997109           0.959077  0.038032
#          QUESTION_ANSWERING                 0.984425           0.899066  0.085359
#          CLASSIFICATION                     0.980436           0.914609  0.065828
#          CLUSTERING                         0.993968           0.954111  0.039857
#          RETRIEVAL_DOCUMENT                 0.995030           0.953517  0.041513
#          RETRIEVAL_QUERY                    0.972311           0.889050  0.083261
#          FACT_VERIFICATION                  0.981177           0.892366  0.088811
# Alt      SEMANTIC_SIMILARITY                0.997718           0.973772  0.023947
#          QUESTION_ANSWERING                 0.985752           0.916921  0.068831
#          CLASSIFICATION                     0.988074           0.960987  0.027087
#          CLUSTERING                         0.994682           0.980497  0.014185
#          RETRIEVAL_DOCUMENT                 0.994648           0.964293  0.030356
#          RETRIEVAL_QUERY                    0.981498           0.922341  0.059157
#          FACT_VERIFICATION                  0.985763           0.924770  0.060994
# --- ordered ---
#                               semantically_identical  lexically_similar     delta
# Setting  Task Type
# Main     FACT_VERIFICATION                  0.981177           0.892366  0.088811
# Original QUESTION_ANSWERING                 0.984825           0.898482  0.086343
# Main     QUESTION_ANSWERING                 0.984425           0.899066  0.085359
#          RETRIEVAL_QUERY                    0.972311           0.889050  0.083261
# Original FACT_VERIFICATION                  0.986830           0.909675  0.077155
#          RETRIEVAL_QUERY                    0.985738           0.910084  0.075654
# Alt      QUESTION_ANSWERING                 0.985752           0.916921  0.068831
# Main     CLASSIFICATION                     0.980436           0.914609  0.065828
# Alt      FACT_VERIFICATION                  0.985763           0.924770  0.060994
#          RETRIEVAL_QUERY                    0.981498           0.922341  0.059157
# Original CLASSIFICATION                     0.987050           0.929606  0.057444
# Main     RETRIEVAL_DOCUMENT                 0.995030           0.953517  0.041513
#          CLUSTERING                         0.993968           0.954111  0.039857
# Original RETRIEVAL_DOCUMENT                 0.995890           0.957301  0.038589
# Main     SEMANTIC_SIMILARITY                0.997109           0.959077  0.038032
# Alt      RETRIEVAL_DOCUMENT                 0.994648           0.964293  0.030356
# Original CLUSTERING                         0.995677           0.966805  0.028872
# Alt      CLASSIFICATION                     0.988074           0.960987  0.027087
# Original SEMANTIC_SIMILARITY                0.997794           0.970933  0.026861
# Alt      SEMANTIC_SIMILARITY                0.997718           0.973772  0.023947
#          CLUSTERING                         0.994682           0.980497  0.014185
# # L1
#
#                               semantically_identical  lexically_similar      delta
# Setting  Task Type
# Original SEMANTIC_SIMILARITY                2.901578          10.519026  -7.617447
#          QUESTION_ANSWERING                 7.580808          19.704753 -12.123945
#          CLASSIFICATION                     7.063572          16.405605  -9.342033
#          CLUSTERING                         4.078835          11.330158  -7.251323
#          RETRIEVAL_DOCUMENT                 3.947688          12.837708  -8.890020
#          RETRIEVAL_QUERY                    7.414612          18.483660 -11.069048
#          FACT_VERIFICATION                  7.067743          18.594226 -11.526483
# Main     SEMANTIC_SIMILARITY                3.354251          12.554120  -9.199869
#          QUESTION_ANSWERING                 7.711456          19.678749 -11.967293
#          CLASSIFICATION                     8.656327          17.951024  -9.294697
#          CLUSTERING                         4.820952          13.303891  -8.482940
#          RETRIEVAL_DOCUMENT                 4.352501          13.225239  -8.872738
#          RETRIEVAL_QUERY                   10.421610          20.682896 -10.261286
#          FACT_VERIFICATION                  8.483453          20.292357 -11.808904
# Alt      SEMANTIC_SIMILARITY                2.948793           9.970297  -7.021504
#          QUESTION_ANSWERING                 7.444575          17.861544 -10.416970
#          CLASSIFICATION                     6.806107          12.145342  -5.339235
#          CLUSTERING                         4.469010           8.674672  -4.205662
#          RETRIEVAL_DOCUMENT                 4.559093          11.740893  -7.181800
#          RETRIEVAL_QUERY                    8.457980          17.229176  -8.771196
#          FACT_VERIFICATION                  7.403331          16.978476  -9.575144
# --- ordered ---
#                               semantically_identical  lexically_similar      delta
# Setting  Task Type
# Alt      CLUSTERING                         4.469010           8.674672  -4.205662
#          CLASSIFICATION                     6.806107          12.145342  -5.339235
#          SEMANTIC_SIMILARITY                2.948793           9.970297  -7.021504
#          RETRIEVAL_DOCUMENT                 4.559093          11.740893  -7.181800
# Original CLUSTERING                         4.078835          11.330158  -7.251323
#          SEMANTIC_SIMILARITY                2.901578          10.519026  -7.617447
# Main     CLUSTERING                         4.820952          13.303891  -8.482940
# Alt      RETRIEVAL_QUERY                    8.457980          17.229176  -8.771196
# Main     RETRIEVAL_DOCUMENT                 4.352501          13.225239  -8.872738
# Original RETRIEVAL_DOCUMENT                 3.947688          12.837708  -8.890020
# Main     SEMANTIC_SIMILARITY                3.354251          12.554120  -9.199869
#          CLASSIFICATION                     8.656327          17.951024  -9.294697
# Original CLASSIFICATION                     7.063572          16.405605  -9.342033
# Alt      FACT_VERIFICATION                  7.403331          16.978476  -9.575144
# Main     RETRIEVAL_QUERY                   10.421610          20.682896 -10.261286
# Alt      QUESTION_ANSWERING                 7.444575          17.861544 -10.416970
# Original RETRIEVAL_QUERY                    7.414612          18.483660 -11.069048
#          FACT_VERIFICATION                  7.067743          18.594226 -11.526483
# Main     FACT_VERIFICATION                  8.483453          20.292357 -11.808904
#          QUESTION_ANSWERING                 7.711456          19.678749 -11.967293
# Original QUESTION_ANSWERING                 7.580808          19.704753 -12.123945
#
#
# # L2
#                               semantically_identical  lexically_similar     delta
# Setting  Task Type
# Original SEMANTIC_SIMILARITY                0.066429           0.241111 -0.174682
#          QUESTION_ANSWERING                 0.174212           0.450595 -0.276384
#          CLASSIFICATION                     0.160934           0.375216 -0.214282
#          CLUSTERING                         0.092979           0.257662 -0.164683
#          RETRIEVAL_DOCUMENT                 0.090664           0.292229 -0.201565
#          RETRIEVAL_QUERY                    0.168892           0.424066 -0.255173
#          FACT_VERIFICATION                  0.162297           0.425030 -0.262733
# Main     SEMANTIC_SIMILARITY                0.076040           0.286086 -0.210046
#          QUESTION_ANSWERING                 0.176492           0.449298 -0.272805
#          CLASSIFICATION                     0.197806           0.413258 -0.215452
#          CLUSTERING                         0.109840           0.302949 -0.193110
#          RETRIEVAL_DOCUMENT                 0.099696           0.304902 -0.205207
#          RETRIEVAL_QUERY                    0.235327           0.471062 -0.235736
#          FACT_VERIFICATION                  0.194027           0.463970 -0.269943
# Alt      SEMANTIC_SIMILARITY                0.067551           0.229035 -0.161484
#          QUESTION_ANSWERING                 0.168808           0.407624 -0.238816
#          CLASSIFICATION                     0.154444           0.279332 -0.124888
#          CLUSTERING                         0.103130           0.197499 -0.094369
#          RETRIEVAL_DOCUMENT                 0.103457           0.267235 -0.163779
#          RETRIEVAL_QUERY                    0.192363           0.394104 -0.201742
#          FACT_VERIFICATION                  0.168742           0.387893 -0.219151
# --- ordered ---
#                               semantically_identical  lexically_similar     delta
# Setting  Task Type
# Alt      CLUSTERING                         0.103130           0.197499 -0.094369
#          CLASSIFICATION                     0.154444           0.279332 -0.124888
#          SEMANTIC_SIMILARITY                0.067551           0.229035 -0.161484
#          RETRIEVAL_DOCUMENT                 0.103457           0.267235 -0.163779
# Original CLUSTERING                         0.092979           0.257662 -0.164683
#          SEMANTIC_SIMILARITY                0.066429           0.241111 -0.174682
# Main     CLUSTERING                         0.109840           0.302949 -0.193110
# Original RETRIEVAL_DOCUMENT                 0.090664           0.292229 -0.201565
# Alt      RETRIEVAL_QUERY                    0.192363           0.394104 -0.201742
# Main     RETRIEVAL_DOCUMENT                 0.099696           0.304902 -0.205207
#          SEMANTIC_SIMILARITY                0.076040           0.286086 -0.210046
# Original CLASSIFICATION                     0.160934           0.375216 -0.214282
# Main     CLASSIFICATION                     0.197806           0.413258 -0.215452
# Alt      FACT_VERIFICATION                  0.168742           0.387893 -0.219151
# Main     RETRIEVAL_QUERY                    0.235327           0.471062 -0.235736
# Alt      QUESTION_ANSWERING                 0.168808           0.407624 -0.238816
# Original RETRIEVAL_QUERY                    0.168892           0.424066 -0.255173
#          FACT_VERIFICATION                  0.162297           0.425030 -0.262733
# Main     FACT_VERIFICATION                  0.194027           0.463970 -0.269943
#          QUESTION_ANSWERING                 0.176492           0.449298 -0.272805
# Original QUESTION_ANSWERING                 0.174212           0.450595 -0.276384

# %%
import threading


def update_json_safely(lock: threading.Lock, update_dict, debug: bool = False):

	with lock:

		with open(ALL_EXAMS_DATA, "r", encoding="utf-8") as f:
			data = json.load(f)
			if not isinstance(data, dict):

				data = {}	# Ensure we have a dictionary to work with

	data.update(update_dict)
	for k, v in update_dict.items():
		if k not in data:
			print(f"Updating json with {k}")

		# Write the entire modified structure back to the file
	with lock:

		with open(ALL_EXAMS_DATA, "w", encoding="utf-8") as f:
			json.dump(data, f, ensure_ascii=False, indent=4)

		# if debug:
		#     print(
		#         f"[Thread {threading.get_ident()}] Lock released for {filename}."
		#     )
	return data
